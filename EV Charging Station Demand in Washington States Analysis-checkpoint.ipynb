# %% [markdown]
# ## EV Charging Station Demand in Washington States

# %% [markdown]
# ## Introduction
# In this study, We will be analysing data to identify the current usage of EV cars in Washington states and build models to see if there will any demand in EV charging stations in Washington states in the next 10 years.
#
#
# <u>**Table of Contents**</u>
# 1. [Introduction](#Introduction)
# 2. [Data Importing](#Data-Importing)
# 3. [Data Preparation](#Data-Preparation)
# 4. [Modeling and Evaluation using ARIMA](#Modeling-and-Evaluation-using-ARIMA)
# - [King County EV Car Count Future Prediction](#King-County-EV-Car-Count-Future-Prediction)
# - [Snohomish County EV Car Count Future Prediction](#Snohomish-County-EV-Car-Count-Future-Prediction)
# - [Pierce EV Car Count Future Prediction](#Pierce-EV-Car-Count-Future-Prediction)
# 5. [Conclusions](#Conclusions)

# %% [markdown]
# ## Data Importing
# We are using data on electric vehicle title and registration activity in Washington state from the state’s API.
# https://data.wa.gov/Transportation/Electric-Vehicle-Title-and-Registration-Activity/rpr4-cgyd

# %%
#importing the data back into the notebook
import requests
import time
import pandas as pd
df=pd.read_csv('Electric_Vehicle_Title_and_Registration_Activity.csv', index_col=0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 681315 entries, Battery Electric Vehicle (BEV) to Plug-in Hybrid Electric Vehicle (PHEV)
# Data columns (total 34 columns):
#  #   Column                                                          Non-Null Count   Dtype
# ---  ------                                                          --------------   -----
#  0   VIN (1-10)                                                      681315 non-null  object
#  1   DOL Vehicle ID                                                  681315 non-null  int64
#  2   Model Year                                                      681315 non-null  int64
#  3   Make                                                            681315 non-null  object
#  4   Model                                                           681110 non-null  object
#  5   Vehicle Primary Use                                             681315 non-null  object
#  6   Electric Range                                                  681315 non-null  int64
#  7   Odometer Reading                                                681315 non-null  object
#  8   Odometer Code                                                   681315 non-null  object
#  9   New or Used Vehicle                                             681315 non-null  object
#  10  Sale Price                                                      681315 non-null  object
#  11  Sale Date                                                       204373 non-null  object
#  12  Base MSRP                                                       681315 non-null  object
#  13  Transaction Type                                                681315 non-null  object
#  14  DOL Transaction Date                                            681315 non-null  object
#  15  Transaction Year                                                681315 non-null  int64
#  16  County                                                          681279 non-null  object
#  17  City                                                            681249 non-null  object
#  18  State of Residence                                              681314 non-null  object
#  19  Postal Code                                                     681271 non-null  float64
#  20  2015 HB 2778 Exemption Eligibility                              681315 non-null  object
#  21  2019 HB 2042 Clean Alternative Fuel Vehicle (CAFV) Eligibility  681315 non-null  object
#  22  Meets 2019 HB 2042 Electric Range Requirement                   681315 non-null  bool
#  23  Meets 2019 HB 2042 Sale Date Requirement                        681315 non-null  bool
#  24  Meets 2019 HB 2042 Sale Price/Value Requirement                 681315 non-null  bool
#  25  2019 HB 2042: Battery Range Requirement                         681315 non-null  object
#  26  2019 HB 2042: Purchase Date Requirement                         681315 non-null  object
#  27  2019 HB 2042: Sale Price/Value Requirement                      681315 non-null  object
#  28  Electric Vehicle Fee Paid                                       681315 non-null  object
#  29  Transportation Electrification Fee Paid                         590284 non-null  object
#  30  Hybrid Vehicle Electrification Fee Paid                         590284 non-null  object
#  31  2020 Census Tract                                               681279 non-null  float64
#  32  Legislative District                                            678957 non-null  float64
#  33  Electric Utility                                                678062 non-null  object
# dtypes: bool(3), float64(3), int64(4), object(24)
# memory usage: 168.3+ MB

# %% [markdown]
# ## Data Preparation

# %%
#display all columns
#pd.set_option('max_columns', None)
#df.head()

# %%
# dropping unneed goverment columns
df.drop(['Electric Vehicle Fee Paid'], axis=1, inplace=True)
df.drop(['2015 HB 2778 Exemption Eligibility'], axis=1, inplace=True)
df.drop(['2019 HB 2042 Clean Alternative Fuel Vehicle (CAFV) Eligibility'], axis=1, inplace=True)
df.drop(['Meets 2019 HB 2042 Electric Range Requirement'], axis=1, inplace=True)
df.drop(['Meets 2019 HB 2042 Sale Date Requirement'], axis=1, inplace=True)
df.drop(['Meets 2019 HB 2042 Sale Price/Value Requirement'], axis=1, inplace=True)
df.drop(['2019 HB 2042: Battery Range Requirement'], axis=1, inplace=True)
df.drop(['2019 HB 2042: Purchase Date Requirement'], axis=1, inplace=True)
df.drop(['2019 HB 2042: Sale Price/Value Requirement'], axis=1, inplace=True)
df.drop(['Transportation Electrification Fee Paid'], axis=1, inplace=True)
df.drop(['Hybrid Vehicle Electrification Fee Paid'], axis=1, inplace=True)
df.drop(['2020 Census Tract'], axis=1, inplace=True)
df.drop(['Legislative District'], axis=1, inplace=True)
df.drop(['Electric Utility'], axis=1, inplace=True)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 681315 entries, Battery Electric Vehicle (BEV) to Plug-in Hybrid Electric Vehicle (PHEV)
# Data columns (total 20 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   VIN (1-10)            681315 non-null  object
#  1   DOL Vehicle ID        681315 non-null  int64
#  2   Model Year            681315 non-null  int64
#  3   Make                  681315 non-null  object
#  4   Model                 681110 non-null  object
#  5   Vehicle Primary Use   681315 non-null  object
#  6   Electric Range        681315 non-null  int64
#  7   Odometer Reading      681315 non-null  object
#  8   Odometer Code         681315 non-null  object
#  9   New or Used Vehicle   681315 non-null  object
#  10  Sale Price            681315 non-null  object
#  11  Sale Date             204373 non-null  object
#  12  Base MSRP             681315 non-null  object
#  13  Transaction Type      681315 non-null  object
#  14  DOL Transaction Date  681315 non-null  object
#  15  Transaction Year      681315 non-null  int64
#  16  County                681279 non-null  object
#  17  City                  681249 non-null  object
#  18  State of Residence    681314 non-null  object
#  19  Postal Code           681271 non-null  float64
# dtypes: float64(1), int64(4), object(15)
# memory usage: 109.2+ MB

# %%
df[df.duplicated()] #Exact Duplicates
# Out:
#                                         VIN (1-10)  DOL Vehicle ID  \
# Clean Alternative Fuel Vehicle Type
# Battery Electric Vehicle (BEV)          537LS7D49B       145144359
# Plug-in Hybrid Electric Vehicle (PHEV)  LYVBR0DL8K       306805859
# Plug-in Hybrid Electric Vehicle (PHEV)  SALWR4RY9M       145573200
# Battery Electric Vehicle (BEV)          5YJYGDEF5M       137402100
# Battery Electric Vehicle (BEV)          1N4BZ0CP3H       298216292
# Battery Electric Vehicle (BEV)          5YJSA1H12E         4580649
# Plug-in Hybrid Electric Vehicle (PHEV)  JTDKN3DP3C       141585426
# Battery Electric Vehicle (BEV)          5YJSA1E27F       162325614
# Battery Electric Vehicle (BEV)          5YJSA1E27F       162325614
# Plug-in Hybrid Electric Vehicle (PHEV)  WBY1Z8C52H       230331370
# Battery Electric Vehicle (BEV)          WMEEJ9AA6D       216583902
# Battery Electric Vehicle (BEV)          5YJ3E1EB9L         3359947
# Battery Electric Vehicle (BEV)          5YJ3E1EB9K       196981277
# Battery Electric Vehicle (BEV)          1G1FX6S0XJ       267880000
# Battery Electric Vehicle (BEV)          1N4AZ0CP6F       100972154
#
#                                         Model Year            Make  \
# Clean Alternative Fuel Vehicle Type
# Battery Electric Vehicle (BEV)                2011  AZURE DYNAMICS
# Plug-in Hybrid Electric Vehicle (PHEV)        2019           VOLVO
# Plug-in Hybrid Electric Vehicle (PHEV)        2021      LAND ROVER
# Battery Electric Vehicle (BEV)                2021           TESLA
# Battery Electric Vehicle (BEV)                2017          NISSAN
# Battery Electric Vehicle (BEV)                2014           TESLA
# Plug-in Hybrid Electric Vehicle (PHEV)        2012          TOYOTA
# Battery Electric Vehicle (BEV)                2015           TESLA
# Battery Electric Vehicle (BEV)                2015           TESLA
# Plug-in Hybrid Electric Vehicle (PHEV)        2017             BMW
# Battery Electric Vehicle (BEV)                2013           SMART
# Battery Electric Vehicle (BEV)                2020           TESLA
# Battery Electric Vehicle (BEV)                2019           TESLA
# Battery Electric Vehicle (BEV)                2018       CHEVROLET
# Battery Electric Vehicle (BEV)                2015          NISSAN
#
#                                                            Model  \
# Clean Alternative Fuel Vehicle Type
# Battery Electric Vehicle (BEV)          Transit Connect Electric
# Plug-in Hybrid Electric Vehicle (PHEV)                      XC60
# Plug-in Hybrid Electric Vehicle (PHEV)         Range Rover Sport
# Battery Electric Vehicle (BEV)                           Model Y
# Battery Electric Vehicle (BEV)                              Leaf
# Battery Electric Vehicle (BEV)                           Model S
# Plug-in Hybrid Electric Vehicle (PHEV)             Prius Plug-in
# Battery Electric Vehicle (BEV)                           Model S
# Battery Electric Vehicle (BEV)                           Model S
# Plug-in Hybrid Electric Vehicle (PHEV)                        i3
# Battery Electric Vehicle (BEV)             Fortwo Electric Drive
# Battery Electric Vehicle (BEV)                           Model 3
# Battery Electric Vehicle (BEV)                           Model 3
# Battery Electric Vehicle (BEV)                           Bolt EV
# Battery Electric Vehicle (BEV)                              Leaf
#
#                                        Vehicle Primary Use  Electric Range  \
# Clean Alternative Fuel Vehicle Type
# Battery Electric Vehicle (BEV)                  Commercial              56
# Plug-in Hybrid Electric Vehicle (PHEV)           Passenger              17
# Plug-in Hybrid Electric Vehicle (PHEV)           Passenger              19
# Battery Electric Vehicle (BEV)                   Passenger               0
# Battery Electric Vehicle (BEV)                   Passenger             107
# Battery Electric Vehicle (BEV)                   Passenger             208
# Plug-in Hybrid Electric Vehicle (PHEV)           Passenger               6
# Battery Electric Vehicle (BEV)                   Passenger             208
# Battery Electric Vehicle (BEV)                   Passenger             208
# Plug-in Hybrid Electric Vehicle (PHEV)           Passenger              97
# Battery Electric Vehicle (BEV)                   Passenger              68
# Battery Electric Vehicle (BEV)                   Passenger             322
# Battery Electric Vehicle (BEV)                   Passenger             220
# Battery Electric Vehicle (BEV)                   Passenger             238
# Battery Electric Vehicle (BEV)                   Passenger              84
#
#                                        Odometer Reading  \
# Clean Alternative Fuel Vehicle Type
# Battery Electric Vehicle (BEV)                   11,196
# Plug-in Hybrid Electric Vehicle (PHEV)                0
# Plug-in Hybrid Electric Vehicle (PHEV)                0
# Battery Electric Vehicle (BEV)                        0
# Battery Electric Vehicle (BEV)                        0
# Battery Electric Vehicle (BEV)                        0
# Plug-in Hybrid Electric Vehicle (PHEV)                0
# Battery Electric Vehicle (BEV)                        0
# Battery Electric Vehicle (BEV)                        0
# Plug-in Hybrid Electric Vehicle (PHEV)                0
# Battery Electric Vehicle (BEV)                        0
# Battery Electric Vehicle (BEV)                        0
# Battery Electric Vehicle (BEV)                        0
# Battery Electric Vehicle (BEV)                        0
# Battery Electric Vehicle (BEV)                        0
#
#                                                                             Odometer Code  \
# Clean Alternative Fuel Vehicle Type
# Battery Electric Vehicle (BEV)                                             Actual Mileage
# Plug-in Hybrid Electric Vehicle (PHEV)  Odometer reading is not collected at time of r...
# Plug-in Hybrid Electric Vehicle (PHEV)  Odometer reading is not collected at time of r...
# Battery Electric Vehicle (BEV)          Odometer reading is not collected at time of r...
# Battery Electric Vehicle (BEV)          Odometer reading is not collected at time of r...
# Battery Electric Vehicle (BEV)          Odometer reading is not collected at time of r...
# Plug-in Hybrid Electric Vehicle (PHEV)  Odometer reading is not collected at time of r...
# Battery Electric Vehicle (BEV)          Odometer reading is not collected at time of r...
# Battery Electric Vehicle (BEV)          Odometer reading is not collected at time of r...
# Plug-in Hybrid Electric Vehicle (PHEV)  Odometer reading is not collected at time of r...
# Battery Electric Vehicle (BEV)          Odometer reading is not collected at time of r...
# Battery Electric Vehicle (BEV)          Odometer reading is not collected at time of r...
# Battery Electric Vehicle (BEV)          Odometer reading is not collected at time of r...
# Battery Electric Vehicle (BEV)          Odometer reading is not collected at time of r...
# Battery Electric Vehicle (BEV)          Odometer reading is not collected at time of r...
#
#                                        New or Used Vehicle Sale Price  \
# Clean Alternative Fuel Vehicle Type
# Battery Electric Vehicle (BEV)                        Used          0
# Plug-in Hybrid Electric Vehicle (PHEV)                Used          0
# Plug-in Hybrid Electric Vehicle (PHEV)                Used          0
# Battery Electric Vehicle (BEV)                        Used          0
# Battery Electric Vehicle (BEV)                        Used          0
# Battery Electric Vehicle (BEV)                        Used          0
# Plug-in Hybrid Electric Vehicle (PHEV)                Used          0
# Battery Electric Vehicle (BEV)                        Used          0
# Battery Electric Vehicle (BEV)                        Used          0
# Plug-in Hybrid Electric Vehicle (PHEV)                Used          0
# Battery Electric Vehicle (BEV)                        Used          0
# Battery Electric Vehicle (BEV)                        Used          0
# Battery Electric Vehicle (BEV)                        Used          0
# Battery Electric Vehicle (BEV)                        Used          0
# Battery Electric Vehicle (BEV)                        Used          0
#
#                                        Sale Date Base MSRP  \
# Clean Alternative Fuel Vehicle Type
# Battery Electric Vehicle (BEV)               NaN         0
# Plug-in Hybrid Electric Vehicle (PHEV)       NaN    52,900
# Plug-in Hybrid Electric Vehicle (PHEV)       NaN         0
# Battery Electric Vehicle (BEV)               NaN         0
# Battery Electric Vehicle (BEV)               NaN         0
# Battery Electric Vehicle (BEV)               NaN    69,900
# Plug-in Hybrid Electric Vehicle (PHEV)       NaN         0
# Battery Electric Vehicle (BEV)               NaN         0
# Battery Electric Vehicle (BEV)               NaN         0
# Plug-in Hybrid Electric Vehicle (PHEV)       NaN         0
# Battery Electric Vehicle (BEV)               NaN         0
# Battery Electric Vehicle (BEV)               NaN         0
# Battery Electric Vehicle (BEV)               NaN         0
# Battery Electric Vehicle (BEV)               NaN         0
# Battery Electric Vehicle (BEV)               NaN         0
#
#                                             Transaction Type  \
# Clean Alternative Fuel Vehicle Type
# Battery Electric Vehicle (BEV)          Registration Renewal
# Plug-in Hybrid Electric Vehicle (PHEV)  Registration Renewal
# Plug-in Hybrid Electric Vehicle (PHEV)  Registration Renewal
# Battery Electric Vehicle (BEV)          Registration Renewal
# Battery Electric Vehicle (BEV)          Registration Renewal
# Battery Electric Vehicle (BEV)          Registration Renewal
# Plug-in Hybrid Electric Vehicle (PHEV)  Registration Renewal
# Battery Electric Vehicle (BEV)          Registration Renewal
# Battery Electric Vehicle (BEV)          Registration Renewal
# Plug-in Hybrid Electric Vehicle (PHEV)  Registration Renewal
# Battery Electric Vehicle (BEV)          Registration Renewal
# Battery Electric Vehicle (BEV)          Registration Renewal
# Battery Electric Vehicle (BEV)          Registration Renewal
# Battery Electric Vehicle (BEV)          Registration Renewal
# Battery Electric Vehicle (BEV)          Registration Renewal
#
#                                        DOL Transaction Date  Transaction Year  \
# Clean Alternative Fuel Vehicle Type
# Battery Electric Vehicle (BEV)                April 02 2014              2014
# Plug-in Hybrid Electric Vehicle (PHEV)     December 18 2020              2020
# Plug-in Hybrid Electric Vehicle (PHEV)    September 23 2022              2022
# Battery Electric Vehicle (BEV)             December 12 2022              2022
# Battery Electric Vehicle (BEV)               August 21 2020              2020
# Battery Electric Vehicle (BEV)            September 04 2021              2021
# Plug-in Hybrid Electric Vehicle (PHEV)         July 06 2021              2021
# Battery Electric Vehicle (BEV)               August 26 2019              2019
# Battery Electric Vehicle (BEV)                 July 21 2022              2022
# Plug-in Hybrid Electric Vehicle (PHEV)         July 14 2018              2018
# Battery Electric Vehicle (BEV)              January 30 2020              2020
# Battery Electric Vehicle (BEV)             December 15 2021              2021
# Battery Electric Vehicle (BEV)            September 09 2022              2022
# Battery Electric Vehicle (BEV)                March 10 2021              2021
# Battery Electric Vehicle (BEV)              October 05 2017              2017
#
#                                               County          City  \
# Clean Alternative Fuel Vehicle Type
# Battery Electric Vehicle (BEV)                  King       SEATTLE
# Plug-in Hybrid Electric Vehicle (PHEV)  Grays Harbor  OCEAN SHORES
# Plug-in Hybrid Electric Vehicle (PHEV)          King        AUBURN
# Battery Electric Vehicle (BEV)                  King        RENTON
# Battery Electric Vehicle (BEV)                  King       SEATTLE
# Battery Electric Vehicle (BEV)                  King       SEATTLE
# Plug-in Hybrid Electric Vehicle (PHEV)          King       SEATTLE
# Battery Electric Vehicle (BEV)                  King     SAMMAMISH
# Battery Electric Vehicle (BEV)                  King     SAMMAMISH
# Plug-in Hybrid Electric Vehicle (PHEV)          King       SEATTLE
# Battery Electric Vehicle (BEV)                  King     SHORELINE
# Battery Electric Vehicle (BEV)                  King      ISSAQUAH
# Battery Electric Vehicle (BEV)               Spokane        CHENEY
# Battery Electric Vehicle (BEV)              Thurston       OLYMPIA
# Battery Electric Vehicle (BEV)                  King       REDMOND
#
#                                        State of Residence  Postal Code
# Clean Alternative Fuel Vehicle Type
# Battery Electric Vehicle (BEV)                         WA      98107.0
# Plug-in Hybrid Electric Vehicle (PHEV)                 WA      98569.0
# Plug-in Hybrid Electric Vehicle (PHEV)                 WA      98001.0
# Battery Electric Vehicle (BEV)                         WA      98056.0
# Battery Electric Vehicle (BEV)                         WA      98117.0
# Battery Electric Vehicle (BEV)                         WA      98117.0
# Plug-in Hybrid Electric Vehicle (PHEV)                 WA      98118.0
# Battery Electric Vehicle (BEV)                         WA      98074.0
# Battery Electric Vehicle (BEV)                         WA      98074.0
# Plug-in Hybrid Electric Vehicle (PHEV)                 WA      98122.0
# Battery Electric Vehicle (BEV)                         WA      98155.0
# Battery Electric Vehicle (BEV)                         WA      98029.0
# Battery Electric Vehicle (BEV)                         WA      99004.0
# Battery Electric Vehicle (BEV)                         WA      98503.0
# Battery Electric Vehicle (BEV)                         WA      98072.0

# %%
# delete duplicates
df.drop_duplicates(inplace=True)

# verifying that duplicates have been removed
len(df[df.duplicated()])
# Out:
# 0

# %%
# checking if there's null values in the dataset
df.isna().sum()
# Out:
# VIN (1-10)                   0
# DOL Vehicle ID               0
# Model Year                   0
# Make                         0
# Model                      205
# Vehicle Primary Use          0
# Electric Range               0
# Odometer Reading             0
# Odometer Code                0
# New or Used Vehicle          0
# Sale Price                   0
# Sale Date               476927
# Base MSRP                    0
# Transaction Type             0
# DOL Transaction Date         0
# Transaction Year             0
# County                      36
# City                        66
# State of Residence           1
# Postal Code                 44
# dtype: int64

# %% [markdown]
# 'Sale Date' column seems to be missing quite a bit of information. We have the dta of 'DOL transation date' which is the date when they register the car with the state. In general, the 'DOL transaction date' and the actual vehicle sale are very close (within a few weeks). The 'Sale date' here aren't too meaningful to us and seems to be missing a lot of data and so we are going to drop this colomun.

# %%
df.drop(['Sale Date'], axis=1, inplace=True) 
df.drop(['Base MSRP'], axis=1, inplace=True) # we have sale price already and so don't need this one
df.drop(['Transaction Year'], axis=1, inplace=True) # we have DOL transaction date also and so don't need this either

# %%
df.isna().sum() #checking the null one again after dropping the columns that are no longer needed
# Out:
# VIN (1-10)                0
# DOL Vehicle ID            0
# Model Year                0
# Make                      0
# Model                   205
# Vehicle Primary Use       0
# Electric Range            0
# Odometer Reading          0
# Odometer Code             0
# New or Used Vehicle       0
# Sale Price                0
# Transaction Type          0
# DOL Transaction Date      0
# County                   36
# City                     66
# State of Residence        1
# Postal Code              44
# dtype: int64

# %%
#dropping null values
df.dropna(subset=['Model'], inplace=True)
df.dropna(subset=['City'], inplace=True)
df.dropna(subset=['County'], inplace=True)
df.dropna(subset=['State of Residence'], inplace=True)
df.dropna(subset=['Postal Code'], inplace=True)
df.isna().sum()
# Out:
# VIN (1-10)              0
# DOL Vehicle ID          0
# Model Year              0
# Make                    0
# Model                   0
# Vehicle Primary Use     0
# Electric Range          0
# Odometer Reading        0
# Odometer Code           0
# New or Used Vehicle     0
# Sale Price              0
# Transaction Type        0
# DOL Transaction Date    0
# County                  0
# City                    0
# State of Residence      0
# Postal Code             0
# dtype: int64

# %% [markdown]
# <h5> The goal is this project is to focusing on the data analysis in Washington State. Therefore, we are only doing "State of Residence' = WA </h5>

# %%
df=df[df['State of Residence']=='WA']
from matplotlib import pyplot as plt
WA_States_EV_Car_Counts = df['County'].value_counts()/len(df['County'])*100 
WA_States_EV_Car_Counts.plot(kind= 'bar', figsize=(17,8)) # plots bar chart
plt.suptitle("Electric Vehicles Counts Per County in Washington State 2023") # title of plot
plt.xlabel('County In Washington State 2023') # label for x axis
plt.ylabel('Percent %'); # label for y axis

df['County'].value_counts()
# Out:
# King            368002
# Snohomish        74322
# Pierce           50991
# Clark            37365
# Kitsap           24104
# Thurston         22729
# Whatcom          17289
# Spokane          15575
# Benton            8003
# Island            7642
# Skagit            7233
# Clallam           4358
# Jefferson         4203
# San Juan          4098
# Chelan            3498
# Yakima            3252
# Mason             3250
# Cowlitz           3230
# Lewis             2604
# Grays Harbor      2306
# Franklin          2031
# Kittitas          1806
# Grant             1688
# Walla Walla       1629
# Douglas           1327
# Klickitat         1046
# Whitman           1017
# Stevens            805
# Okanogan           744
# Pacific            731
# Skamania           647
# Asotin             284
# Adams              191
# Pend Oreille       181
# Lincoln            161
# Wahkiakum          152
# Ferry              117
# Columbia            71
# Garfield            17
# Name: County, dtype: int64

# %%
df['DOL Transaction Date'] = pd.to_datetime(df['DOL Transaction Date'])
df.head()
# Out:
#                                      VIN (1-10)  DOL Vehicle ID  Model Year  \
# Clean Alternative Fuel Vehicle Type
# Battery Electric Vehicle (BEV)       WMEEJ9AA7E       349158127        2014
# Battery Electric Vehicle (BEV)       WMEEJ9AA7E       349158127        2014
# Battery Electric Vehicle (BEV)       WVWKR7AU7K       296928922        2019
# Battery Electric Vehicle (BEV)       WVWKR7AU7K       296928922        2019
# Battery Electric Vehicle (BEV)       WVWKR7AU7K       296928922        2019
#
#                                            Make                  Model  \
# Clean Alternative Fuel Vehicle Type
# Battery Electric Vehicle (BEV)            SMART  Fortwo Electric Drive
# Battery Electric Vehicle (BEV)            SMART  Fortwo Electric Drive
# Battery Electric Vehicle (BEV)       VOLKSWAGEN                 e-Golf
# Battery Electric Vehicle (BEV)       VOLKSWAGEN                 e-Golf
# Battery Electric Vehicle (BEV)       VOLKSWAGEN                 e-Golf
#
#                                     Vehicle Primary Use  Electric Range  \
# Clean Alternative Fuel Vehicle Type
# Battery Electric Vehicle (BEV)                Passenger              58
# Battery Electric Vehicle (BEV)                Passenger              58
# Battery Electric Vehicle (BEV)                Passenger             125
# Battery Electric Vehicle (BEV)                Passenger             125
# Battery Electric Vehicle (BEV)                Passenger             125
#
#                                     Odometer Reading  \
# Clean Alternative Fuel Vehicle Type
# Battery Electric Vehicle (BEV)                     0
# Battery Electric Vehicle (BEV)                     0
# Battery Electric Vehicle (BEV)                     5
# Battery Electric Vehicle (BEV)                     0
# Battery Electric Vehicle (BEV)                     0
#
#                                                                          Odometer Code  \
# Clean Alternative Fuel Vehicle Type
# Battery Electric Vehicle (BEV)       Odometer reading is not collected at time of r...
# Battery Electric Vehicle (BEV)       Odometer reading is not collected at time of r...
# Battery Electric Vehicle (BEV)                                          Actual Mileage
# Battery Electric Vehicle (BEV)       Odometer reading is not collected at time of r...
# Battery Electric Vehicle (BEV)       Odometer reading is not collected at time of r...
#
#                                     New or Used Vehicle Sale Price  \
# Clean Alternative Fuel Vehicle Type
# Battery Electric Vehicle (BEV)                     Used          0
# Battery Electric Vehicle (BEV)                     Used          0
# Battery Electric Vehicle (BEV)                      New     23,988
# Battery Electric Vehicle (BEV)                      New          0
# Battery Electric Vehicle (BEV)                     Used          0
#
#                                           Transaction Type  \
# Clean Alternative Fuel Vehicle Type
# Battery Electric Vehicle (BEV)        Registration Renewal
# Battery Electric Vehicle (BEV)        Registration Renewal
# Battery Electric Vehicle (BEV)              Original Title
# Battery Electric Vehicle (BEV)       Original Registration
# Battery Electric Vehicle (BEV)        Registration Renewal
#
#                                     DOL Transaction Date County     City  \
# Clean Alternative Fuel Vehicle Type
# Battery Electric Vehicle (BEV)                2021-06-07   King  SEATTLE
# Battery Electric Vehicle (BEV)                2022-06-06   King  SEATTLE
# Battery Electric Vehicle (BEV)                2019-11-06   King  REDMOND
# Battery Electric Vehicle (BEV)                2019-11-06   King  REDMOND
# Battery Electric Vehicle (BEV)                2020-10-05   King  REDMOND
#
#                                     State of Residence  Postal Code
# Clean Alternative Fuel Vehicle Type
# Battery Electric Vehicle (BEV)                      WA      98102.0
# Battery Electric Vehicle (BEV)                      WA      98102.0
# Battery Electric Vehicle (BEV)                      WA      98052.0
# Battery Electric Vehicle (BEV)                      WA      98052.0
# Battery Electric Vehicle (BEV)                      WA      98052.0

# %%
df['m/y'] = df['DOL Transaction Date'].dt.strftime("%m-%Y")

# %%
df.set_index('DOL Transaction Date', inplace=True)
df.head()
# Out:
#                       VIN (1-10)  DOL Vehicle ID  Model Year        Make  \
# DOL Transaction Date
# 2021-06-07            WMEEJ9AA7E       349158127        2014       SMART
# 2022-06-06            WMEEJ9AA7E       349158127        2014       SMART
# 2019-11-06            WVWKR7AU7K       296928922        2019  VOLKSWAGEN
# 2019-11-06            WVWKR7AU7K       296928922        2019  VOLKSWAGEN
# 2020-10-05            WVWKR7AU7K       296928922        2019  VOLKSWAGEN
#
#                                       Model Vehicle Primary Use  \
# DOL Transaction Date
# 2021-06-07            Fortwo Electric Drive           Passenger
# 2022-06-06            Fortwo Electric Drive           Passenger
# 2019-11-06                           e-Golf           Passenger
# 2019-11-06                           e-Golf           Passenger
# 2020-10-05                           e-Golf           Passenger
#
#                       Electric Range Odometer Reading  \
# DOL Transaction Date
# 2021-06-07                        58                0
# 2022-06-06                        58                0
# 2019-11-06                       125                5
# 2019-11-06                       125                0
# 2020-10-05                       125                0
#
#                                                           Odometer Code  \
# DOL Transaction Date
# 2021-06-07            Odometer reading is not collected at time of r...
# 2022-06-06            Odometer reading is not collected at time of r...
# 2019-11-06                                               Actual Mileage
# 2019-11-06            Odometer reading is not collected at time of r...
# 2020-10-05            Odometer reading is not collected at time of r...
#
#                      New or Used Vehicle Sale Price       Transaction Type  \
# DOL Transaction Date
# 2021-06-07                          Used          0   Registration Renewal
# 2022-06-06                          Used          0   Registration Renewal
# 2019-11-06                           New     23,988         Original Title
# 2019-11-06                           New          0  Original Registration
# 2020-10-05                          Used          0   Registration Renewal
#
#                      County     City State of Residence  Postal Code      m/y
# DOL Transaction Date
# 2021-06-07             King  SEATTLE                 WA      98102.0  06-2021
# 2022-06-06             King  SEATTLE                 WA      98102.0  06-2022
# 2019-11-06             King  REDMOND                 WA      98052.0  11-2019
# 2019-11-06             King  REDMOND                 WA      98052.0  11-2019
# 2020-10-05             King  REDMOND                 WA      98052.0  10-2020

# %%
df=df[(df['Transaction Type']=='Original Title') | 
      (df['Transaction Type']=='Transfer Title')]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 182187 entries, 2019-11-06 to 2014-11-05
# Data columns (total 17 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   VIN (1-10)           182187 non-null  object
#  1   DOL Vehicle ID       182187 non-null  int64
#  2   Model Year           182187 non-null  int64
#  3   Make                 182187 non-null  object
#  4   Model                182187 non-null  object
#  5   Vehicle Primary Use  182187 non-null  object
#  6   Electric Range       182187 non-null  int64
#  7   Odometer Reading     182187 non-null  object
#  8   Odometer Code        182187 non-null  object
#  9   New or Used Vehicle  182187 non-null  object
#  10  Sale Price           182187 non-null  object
#  11  Transaction Type     182187 non-null  object
#  12  County               182187 non-null  object
#  13  City                 182187 non-null  object
#  14  State of Residence   182187 non-null  object
#  15  Postal Code          182187 non-null  float64
#  16  m/y                  182187 non-null  object
# dtypes: float64(1), int64(3), object(13)
# memory usage: 25.0+ MB

# %%
county_dict = {}
for county in list(df['County'].unique()):
    county_dict[county] = df[
        (df['County']==county)&
        (df['Transaction Type']=='Original Title')
    ].resample('M').size().cumsum()

# %%
#filling null values created by resampling with 0's.
df_cumsum = pd.DataFrame(county_dict)
df_cumsum.fillna(0, inplace=True)

# %%
#summing each row to get monthly statewide total 
df_cumsum['State Total'] = df_cumsum.sum(axis=1)

# %%
df_cumsum = df_cumsum.reset_index()

# %%
#plotting statewide EV Count
import matplotlib.pyplot as plt
import seaborn as sns

fig, ax = plt.subplots(figsize=(15,10))
sns.lineplot(x='DOL Transaction Date', y='State Total', data=df_cumsum, ax=ax)
ax.set_xlabel('Date')
ax.set_ylabel('Total Electric Vehicle Count')
ax.set_title('Electric Vehicles on the Road in Washington State (2010-2023)')
ax.set_yticks(range(0,160000,10000))
plt.tight_layout()

# %% [markdown]
# <h4>We can see above that electric vehicles in Washington State have been increasing from 0 to 150000 over the past 13 years <h4>

# %%
df['County'].value_counts()
# Out:
# King            98332
# Snohomish       20374
# Pierce          14461
# Clark           10351
# Kitsap           6228
# Thurston         6215
# Spokane          4422
# Whatcom          4415
# Benton           2137
# Island           1882
# Skagit           1834
# Clallam          1041
# Jefferson         980
# San Juan          940
# Cowlitz           901
# Yakima            888
# Chelan            879
# Mason             817
# Lewis             654
# Franklin          600
# Grays Harbor      569
# Grant             463
# Kittitas          440
# Walla Walla       427
# Douglas           324
# Whitman           271
# Klickitat         259
# Stevens           206
# Pacific           190
# Skamania          183
# Okanogan          177
# Asotin             76
# Adams              58
# Pend Oreille       52
# Wahkiakum          44
# Lincoln            40
# Ferry              31
# Columbia           22
# Garfield            4
# Name: County, dtype: int64

# %%
#plotting county trends

all_counties = ['King', 'Snohomish', 'Pierce', 'Clark', 'Thurston', 'Kitsap', 'Whatcom', 'Spokane', 'Benton', 'Island', 'Skagit', 'Clallam', 'Jefferson', 'San Juan', 'Cowlitz', 'Yakima', 'Chelan', 'Mason', 'Lewis', 'Franklin', 'Grays Harbor', 'Grant', 'Kittitas', 'Walla Walla', 'Douglas', 'Whitman', 'Klickitat', 'Stevens', 'Pacific', 'Skamania', 'Okanogan', 'Asotin', 'Adams', 'Pend Oreille', 'Wahkiakum', 'Lincoln', 'Ferry', 'Columbia', 'Garfield'    ]
fig, ax = plt.subplots(figsize=(20,15))
for county in all_counties:
    sns.lineplot(x='DOL Transaction Date', y=county, data=df_cumsum, ax=ax, 
                 label=county)
ax.set_xlabel('Year')
ax.set_ylabel('EV Car Count')
ax.set_title('Total Electric Vehicle Count by County 2010 - 2023')
ax.legend()

# %%
def EV_car_model_purchased_by_county(df=df, top_n=10, county_list=all_counties):
    
    fig, ax = plt.subplots(figsize=(10, 60), nrows=len(county_list))
    
    for i, county in enumerate(county_list):
        df_county = df[(df['County']==county) & 
                       (df['Transaction Type']=='Original Title')]
        model_count_df = pd.DataFrame(df_county['Model'].value_counts()).reset_index()
        model_count_df.columns=['Model', 'Count']
        sns.barplot(x='Model', y='Count', data=model_count_df.head(top_n), 
                    ax=ax[i])
        ax[i].set_title(f'{county} County (2010-2023)')
    plt.tight_layout();

# %%
EV_car_model_purchased_by_county()

# %% [markdown]
# <h3> Above we can see Tesla, Leaf and Vblt are the top 3 most popular brand when it comes to EV car being purchased in Washington state </h3>

# %%
df_cumsum = df_cumsum.set_index('DOL Transaction Date').resample('M').asfreq()
df_cumsum.info()

# %%
def separate_data_by_county(county, df): 
    df_county = pd.DataFrame(df.loc[:, county])
    df_county.columns=["EV car counts"]
    df_county.head()
    return df_county

# %% [markdown]
# ## Modeling and Evaluation using ARIMA
# SARIMAX(Seasonal Auto-Regressive Integrated Moving Average with eXogenous factors) is an extension of the ARIMA class of models. We are using this to make predction to understand how many more EV cars will be on the road in the following county (King County, Snohomish, Pierce) for the next 10 years.

# %%
#separating all the county data with its EV car counts
county_information = {}
for county in all_counties:
    county_information[county] = {}
    county_information[county]['df']=separate_data_by_county(county, df_cumsum)

# %%
def get_prediction(model, df, test_data, county_name, plot=True):    
    #creating a df with the prediction information
    prediction_df = model.get_forecast(steps=len(test_data)*5).conf_int()
    prediction_df.columns = ['Lower Confidence Interval', 'Upper Confidence Interval']
    prediction_df['Predictions'] = model.get_forecast(steps=len(test_data)*5)\
    .predicted_mean
    #plotting
    if plot==True:
        with plt.style.context('seaborn-whitegrid'):
            fig, ax = plt.subplots(figsize=(20, 15))
            sns.lineplot(data=df, ax=ax)
            sns.lineplot(data=prediction_df, x=prediction_df.index, 
                         y='Predictions', color='red', ax=ax, 
                         label='Predicted Data', ls='--')
            ax.fill_between(prediction_df.index, 
                            y1=prediction_df['Lower Confidence Interval'], 
                            y2=prediction_df['Upper Confidence Interval'],
                            color = 'green', alpha=0.3, 
                            label='Confidence Interval')
            ax.set_xlabel('Year')
            ax.set_ylabel('Electric Vehicles on the Road')
            ax.set_title(f'Predicted Electric Vehicle Count for {county_name}')
            plt.show();
    return prediction_df

# %%
def train_test_split_ts (df, train_size, test_size):
    train_end_idx = int(round(len(df)*train_size,0))
    train_set = df.iloc[0:train_end_idx,:]["EV car counts"]
    test_set = df.iloc[train_end_idx:,:]["EV car counts"]
    return train_set, test_set

# %% [markdown]
# ## King County EV Car Count Future Prediction

# %%
#splitting dataset into train and test sets for validation
train_king, test_king = train_test_split_ts(county_information['King']['df'], 0.80, 0.20)

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
King_County_Model = SARIMAX(county_information['King']['df'], order=(1,1,0), 
                seasonal_order=(0,1,0,12), enforce_invertibility=False, 
                enforce_stationarity=False).fit()
print(King_County_Model.summary())

# %%
df_king_preds = get_prediction(King_County_Model, county_information['King']['df'], test_king, 'King', plot=True)

# %% [markdown]
# ## Snohomish County EV Car Count Future Prediction

# %%
#splitting dataset into train and test sets for validation
train_Snohomish, test_Snohomish = train_test_split_ts(county_information['Snohomish']['df'], 0.80, 0.20)

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
Snohomish_County_Model = SARIMAX(county_information['Snohomish']['df'], order=(1,1,0), 
                seasonal_order=(0,1,0,12), enforce_invertibility=False, 
                enforce_stationarity=False).fit()
print(Snohomish_County_Model.summary())

# %%
df_Snohomish_preds = get_prediction(Snohomish_County_Model, county_information['Snohomish']['df'], test_Snohomish, 'Snohomish', plot=True)

# %% [markdown]
# ## Pierce EV Car Count Future Prediction

# %%
#splitting dataset into train and test sets for validation
train_Pierce, test_Pierce = train_test_split_ts(county_information['Pierce']['df'], 0.80, 0.20)

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
Pierce_County_Model = SARIMAX(county_information['Pierce']['df'], order=(1,1,0), 
                seasonal_order=(0,1,0,12), enforce_invertibility=False, 
                enforce_stationarity=False).fit()
print(Pierce_County_Model.summary())

# %%
df_Pierce_preds = get_prediction(Pierce_County_Model, county_information['Pierce']['df'], test_Pierce, 'Pierce', plot=True)
