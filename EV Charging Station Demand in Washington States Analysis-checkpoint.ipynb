# %% [markdown]
# ## EV Charging Station Demand in Washington States

# %% [markdown]
# ## Introduction
# In this study, We will be analysing data to identify the current usage of EV cars in Washington states and build models to see if there will any demand in EV charging stations in Washington states in the next 10 years.
#
#
# <u>**Table of Contents**</u>
# 1. [Introduction](#Introduction)
# 2. [Data Importing](#Data-Importing)
# 3. [Data Preparation](#Data-Preparation)
# 4. [Modeling and Evaluation using ARIMA](#Modeling-and-Evaluation-using-ARIMA)
#     - [King County EV Car Count Future Prediction](#King-County-EV-Car-Count-Future-Prediction)
#     - [Snohomish County EV Car Count Future Prediction](#Snohomish-County-EV-Car-Count-Future-Prediction)
#     - [Pierce EV Car Count Future Prediction](#Pierce-EV-Car-Count-Future-Prediction)
# 5. [Starbucks Locations Per County in WA State](#Starbucks-Locations-Per-County-in-WA-State)
# 6. [Existing EV Charger Per County in WA State](#Existing-EV-Charger-Per-County-in-WA-State)

# %% [markdown]
# ## Data Importing
# We are using data on electric vehicle title and registration activity in Washington state from the state’s API.
# https://data.wa.gov/Transportation/Electric-Vehicle-Title-and-Registration-Activity/rpr4-cgyd

# %%
#importing the data back into the notebook
import requests
import time
import pandas as pd
df=pd.read_csv('Electric_Vehicle_Title_and_Registration_Activity.csv', index_col=0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 681315 entries, Battery Electric Vehicle (BEV) to Plug-in Hybrid Electric Vehicle (PHEV)
# Data columns (total 34 columns):
#  #   Column                                                          Non-Null Count   Dtype
# ---  ------                                                          --------------   -----
#  0   VIN (1-10)                                                      681315 non-null  object
#  1   DOL Vehicle ID                                                  681315 non-null  int64
#  2   Model Year                                                      681315 non-null  int64
#  3   Make                                                            681315 non-null  object
#  4   Model                                                           681110 non-null  object
#  5   Vehicle Primary Use                                             681315 non-null  object
#  6   Electric Range                                                  681315 non-null  int64
#  7   Odometer Reading                                                681315 non-null  object
#  8   Odometer Code                                                   681315 non-null  object
#  9   New or Used Vehicle                                             681315 non-null  object
#  10  Sale Price                                                      681315 non-null  object
#  11  Sale Date                                                       204373 non-null  object
#  12  Base MSRP                                                       681315 non-null  object
#  13  Transaction Type                                                681315 non-null  object
#  14  DOL Transaction Date                                            681315 non-null  object
#  15  Transaction Year                                                681315 non-null  int64
#  16  County                                                          681279 non-null  object
#  17  City                                                            681249 non-null  object
#  18  State of Residence                                              681314 non-null  object
#  19  Postal Code                                                     681271 non-null  float64
#  20  2015 HB 2778 Exemption Eligibility                              681315 non-null  object
#  21  2019 HB 2042 Clean Alternative Fuel Vehicle (CAFV) Eligibility  681315 non-null  object
#  22  Meets 2019 HB 2042 Electric Range Requirement                   681315 non-null  bool
#  23  Meets 2019 HB 2042 Sale Date Requirement                        681315 non-null  bool
#  24  Meets 2019 HB 2042 Sale Price/Value Requirement                 681315 non-null  bool
#  25  2019 HB 2042: Battery Range Requirement                         681315 non-null  object
#  26  2019 HB 2042: Purchase Date Requirement                         681315 non-null  object
#  27  2019 HB 2042: Sale Price/Value Requirement                      681315 non-null  object
#  28  Electric Vehicle Fee Paid                                       681315 non-null  object
#  29  Transportation Electrification Fee Paid                         590284 non-null  object
#  30  Hybrid Vehicle Electrification Fee Paid                         590284 non-null  object
#  31  2020 Census Tract                                               681279 non-null  float64
#  32  Legislative District                                            678957 non-null  float64
#  33  Electric Utility                                                678062 non-null  object
# dtypes: bool(3), float64(3), int64(4), object(24)
# memory usage: 168.3+ MB

# %% [markdown]
# ## Data Preparation

# %%
#display all columns
#pd.set_option('max_columns', None)
#df.head()

# %%
# dropping unneed goverment columns
df.drop(['Electric Vehicle Fee Paid'], axis=1, inplace=True)
df.drop(['2015 HB 2778 Exemption Eligibility'], axis=1, inplace=True)
df.drop(['2019 HB 2042 Clean Alternative Fuel Vehicle (CAFV) Eligibility'], axis=1, inplace=True)
df.drop(['Meets 2019 HB 2042 Electric Range Requirement'], axis=1, inplace=True)
df.drop(['Meets 2019 HB 2042 Sale Date Requirement'], axis=1, inplace=True)
df.drop(['Meets 2019 HB 2042 Sale Price/Value Requirement'], axis=1, inplace=True)
df.drop(['2019 HB 2042: Battery Range Requirement'], axis=1, inplace=True)
df.drop(['2019 HB 2042: Purchase Date Requirement'], axis=1, inplace=True)
df.drop(['2019 HB 2042: Sale Price/Value Requirement'], axis=1, inplace=True)
df.drop(['Transportation Electrification Fee Paid'], axis=1, inplace=True)
df.drop(['Hybrid Vehicle Electrification Fee Paid'], axis=1, inplace=True)
df.drop(['2020 Census Tract'], axis=1, inplace=True)
df.drop(['Legislative District'], axis=1, inplace=True)
df.drop(['Electric Utility'], axis=1, inplace=True)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 681315 entries, Battery Electric Vehicle (BEV) to Plug-in Hybrid Electric Vehicle (PHEV)
# Data columns (total 20 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   VIN (1-10)            681315 non-null  object
#  1   DOL Vehicle ID        681315 non-null  int64
#  2   Model Year            681315 non-null  int64
#  3   Make                  681315 non-null  object
#  4   Model                 681110 non-null  object
#  5   Vehicle Primary Use   681315 non-null  object
#  6   Electric Range        681315 non-null  int64
#  7   Odometer Reading      681315 non-null  object
#  8   Odometer Code         681315 non-null  object
#  9   New or Used Vehicle   681315 non-null  object
#  10  Sale Price            681315 non-null  object
#  11  Sale Date             204373 non-null  object
#  12  Base MSRP             681315 non-null  object
#  13  Transaction Type      681315 non-null  object
#  14  DOL Transaction Date  681315 non-null  object
#  15  Transaction Year      681315 non-null  int64
#  16  County                681279 non-null  object
#  17  City                  681249 non-null  object
#  18  State of Residence    681314 non-null  object
#  19  Postal Code           681271 non-null  float64
# dtypes: float64(1), int64(4), object(15)
# memory usage: 109.2+ MB

# %%
df[df.duplicated()] #Exact Duplicates
# Out:
#                                         VIN (1-10)  DOL Vehicle ID  \
# Clean Alternative Fuel Vehicle Type
# Battery Electric Vehicle (BEV)          537LS7D49B       145144359
# Plug-in Hybrid Electric Vehicle (PHEV)  LYVBR0DL8K       306805859
# Plug-in Hybrid Electric Vehicle (PHEV)  SALWR4RY9M       145573200
# Battery Electric Vehicle (BEV)          5YJYGDEF5M       137402100
# Battery Electric Vehicle (BEV)          1N4BZ0CP3H       298216292
# Battery Electric Vehicle (BEV)          5YJSA1H12E         4580649
# Plug-in Hybrid Electric Vehicle (PHEV)  JTDKN3DP3C       141585426
# Battery Electric Vehicle (BEV)          5YJSA1E27F       162325614
# Battery Electric Vehicle (BEV)          5YJSA1E27F       162325614
# Plug-in Hybrid Electric Vehicle (PHEV)  WBY1Z8C52H       230331370
# Battery Electric Vehicle (BEV)          WMEEJ9AA6D       216583902
# Battery Electric Vehicle (BEV)          5YJ3E1EB9L         3359947
# Battery Electric Vehicle (BEV)          5YJ3E1EB9K       196981277
# Battery Electric Vehicle (BEV)          1G1FX6S0XJ       267880000
# Battery Electric Vehicle (BEV)          1N4AZ0CP6F       100972154
#
#                                         Model Year            Make  \
# Clean Alternative Fuel Vehicle Type
# Battery Electric Vehicle (BEV)                2011  AZURE DYNAMICS
# Plug-in Hybrid Electric Vehicle (PHEV)        2019           VOLVO
# Plug-in Hybrid Electric Vehicle (PHEV)        2021      LAND ROVER
# Battery Electric Vehicle (BEV)                2021           TESLA
# Battery Electric Vehicle (BEV)                2017          NISSAN
# Battery Electric Vehicle (BEV)                2014           TESLA
# Plug-in Hybrid Electric Vehicle (PHEV)        2012          TOYOTA
# Battery Electric Vehicle (BEV)                2015           TESLA
# Battery Electric Vehicle (BEV)                2015           TESLA
# Plug-in Hybrid Electric Vehicle (PHEV)        2017             BMW
# Battery Electric Vehicle (BEV)                2013           SMART
# Battery Electric Vehicle (BEV)                2020           TESLA
# Battery Electric Vehicle (BEV)                2019           TESLA
# Battery Electric Vehicle (BEV)                2018       CHEVROLET
# Battery Electric Vehicle (BEV)                2015          NISSAN
#
#                                                            Model  \
# Clean Alternative Fuel Vehicle Type
# Battery Electric Vehicle (BEV)          Transit Connect Electric
# Plug-in Hybrid Electric Vehicle (PHEV)                      XC60
# Plug-in Hybrid Electric Vehicle (PHEV)         Range Rover Sport
# Battery Electric Vehicle (BEV)                           Model Y
# Battery Electric Vehicle (BEV)                              Leaf
# Battery Electric Vehicle (BEV)                           Model S
# Plug-in Hybrid Electric Vehicle (PHEV)             Prius Plug-in
# Battery Electric Vehicle (BEV)                           Model S
# Battery Electric Vehicle (BEV)                           Model S
# Plug-in Hybrid Electric Vehicle (PHEV)                        i3
# Battery Electric Vehicle (BEV)             Fortwo Electric Drive
# Battery Electric Vehicle (BEV)                           Model 3
# Battery Electric Vehicle (BEV)                           Model 3
# Battery Electric Vehicle (BEV)                           Bolt EV
# Battery Electric Vehicle (BEV)                              Leaf
#
#                                        Vehicle Primary Use  Electric Range  \
# Clean Alternative Fuel Vehicle Type
# Battery Electric Vehicle (BEV)                  Commercial              56
# Plug-in Hybrid Electric Vehicle (PHEV)           Passenger              17
# Plug-in Hybrid Electric Vehicle (PHEV)           Passenger              19
# Battery Electric Vehicle (BEV)                   Passenger               0
# Battery Electric Vehicle (BEV)                   Passenger             107
# Battery Electric Vehicle (BEV)                   Passenger             208
# Plug-in Hybrid Electric Vehicle (PHEV)           Passenger               6
# Battery Electric Vehicle (BEV)                   Passenger             208
# Battery Electric Vehicle (BEV)                   Passenger             208
# Plug-in Hybrid Electric Vehicle (PHEV)           Passenger              97
# Battery Electric Vehicle (BEV)                   Passenger              68
# Battery Electric Vehicle (BEV)                   Passenger             322
# Battery Electric Vehicle (BEV)                   Passenger             220
# Battery Electric Vehicle (BEV)                   Passenger             238
# Battery Electric Vehicle (BEV)                   Passenger              84
#
#                                        Odometer Reading  \
# Clean Alternative Fuel Vehicle Type
# Battery Electric Vehicle (BEV)                   11,196
# Plug-in Hybrid Electric Vehicle (PHEV)                0
# Plug-in Hybrid Electric Vehicle (PHEV)                0
# Battery Electric Vehicle (BEV)                        0
# Battery Electric Vehicle (BEV)                        0
# Battery Electric Vehicle (BEV)                        0
# Plug-in Hybrid Electric Vehicle (PHEV)                0
# Battery Electric Vehicle (BEV)                        0
# Battery Electric Vehicle (BEV)                        0
# Plug-in Hybrid Electric Vehicle (PHEV)                0
# Battery Electric Vehicle (BEV)                        0
# Battery Electric Vehicle (BEV)                        0
# Battery Electric Vehicle (BEV)                        0
# Battery Electric Vehicle (BEV)                        0
# Battery Electric Vehicle (BEV)                        0
#
#                                                                             Odometer Code  \
# Clean Alternative Fuel Vehicle Type
# Battery Electric Vehicle (BEV)                                             Actual Mileage
# Plug-in Hybrid Electric Vehicle (PHEV)  Odometer reading is not collected at time of r...
# Plug-in Hybrid Electric Vehicle (PHEV)  Odometer reading is not collected at time of r...
# Battery Electric Vehicle (BEV)          Odometer reading is not collected at time of r...
# Battery Electric Vehicle (BEV)          Odometer reading is not collected at time of r...
# Battery Electric Vehicle (BEV)          Odometer reading is not collected at time of r...
# Plug-in Hybrid Electric Vehicle (PHEV)  Odometer reading is not collected at time of r...
# Battery Electric Vehicle (BEV)          Odometer reading is not collected at time of r...
# Battery Electric Vehicle (BEV)          Odometer reading is not collected at time of r...
# Plug-in Hybrid Electric Vehicle (PHEV)  Odometer reading is not collected at time of r...
# Battery Electric Vehicle (BEV)          Odometer reading is not collected at time of r...
# Battery Electric Vehicle (BEV)          Odometer reading is not collected at time of r...
# Battery Electric Vehicle (BEV)          Odometer reading is not collected at time of r...
# Battery Electric Vehicle (BEV)          Odometer reading is not collected at time of r...
# Battery Electric Vehicle (BEV)          Odometer reading is not collected at time of r...
#
#                                        New or Used Vehicle Sale Price  \
# Clean Alternative Fuel Vehicle Type
# Battery Electric Vehicle (BEV)                        Used          0
# Plug-in Hybrid Electric Vehicle (PHEV)                Used          0
# Plug-in Hybrid Electric Vehicle (PHEV)                Used          0
# Battery Electric Vehicle (BEV)                        Used          0
# Battery Electric Vehicle (BEV)                        Used          0
# Battery Electric Vehicle (BEV)                        Used          0
# Plug-in Hybrid Electric Vehicle (PHEV)                Used          0
# Battery Electric Vehicle (BEV)                        Used          0
# Battery Electric Vehicle (BEV)                        Used          0
# Plug-in Hybrid Electric Vehicle (PHEV)                Used          0
# Battery Electric Vehicle (BEV)                        Used          0
# Battery Electric Vehicle (BEV)                        Used          0
# Battery Electric Vehicle (BEV)                        Used          0
# Battery Electric Vehicle (BEV)                        Used          0
# Battery Electric Vehicle (BEV)                        Used          0
#
#                                        Sale Date Base MSRP  \
# Clean Alternative Fuel Vehicle Type
# Battery Electric Vehicle (BEV)               NaN         0
# Plug-in Hybrid Electric Vehicle (PHEV)       NaN    52,900
# Plug-in Hybrid Electric Vehicle (PHEV)       NaN         0
# Battery Electric Vehicle (BEV)               NaN         0
# Battery Electric Vehicle (BEV)               NaN         0
# Battery Electric Vehicle (BEV)               NaN    69,900
# Plug-in Hybrid Electric Vehicle (PHEV)       NaN         0
# Battery Electric Vehicle (BEV)               NaN         0
# Battery Electric Vehicle (BEV)               NaN         0
# Plug-in Hybrid Electric Vehicle (PHEV)       NaN         0
# Battery Electric Vehicle (BEV)               NaN         0
# Battery Electric Vehicle (BEV)               NaN         0
# Battery Electric Vehicle (BEV)               NaN         0
# Battery Electric Vehicle (BEV)               NaN         0
# Battery Electric Vehicle (BEV)               NaN         0
#
#                                             Transaction Type  \
# Clean Alternative Fuel Vehicle Type
# Battery Electric Vehicle (BEV)          Registration Renewal
# Plug-in Hybrid Electric Vehicle (PHEV)  Registration Renewal
# Plug-in Hybrid Electric Vehicle (PHEV)  Registration Renewal
# Battery Electric Vehicle (BEV)          Registration Renewal
# Battery Electric Vehicle (BEV)          Registration Renewal
# Battery Electric Vehicle (BEV)          Registration Renewal
# Plug-in Hybrid Electric Vehicle (PHEV)  Registration Renewal
# Battery Electric Vehicle (BEV)          Registration Renewal
# Battery Electric Vehicle (BEV)          Registration Renewal
# Plug-in Hybrid Electric Vehicle (PHEV)  Registration Renewal
# Battery Electric Vehicle (BEV)          Registration Renewal
# Battery Electric Vehicle (BEV)          Registration Renewal
# Battery Electric Vehicle (BEV)          Registration Renewal
# Battery Electric Vehicle (BEV)          Registration Renewal
# Battery Electric Vehicle (BEV)          Registration Renewal
#
#                                        DOL Transaction Date  Transaction Year  \
# Clean Alternative Fuel Vehicle Type
# Battery Electric Vehicle (BEV)                April 02 2014              2014
# Plug-in Hybrid Electric Vehicle (PHEV)     December 18 2020              2020
# Plug-in Hybrid Electric Vehicle (PHEV)    September 23 2022              2022
# Battery Electric Vehicle (BEV)             December 12 2022              2022
# Battery Electric Vehicle (BEV)               August 21 2020              2020
# Battery Electric Vehicle (BEV)            September 04 2021              2021
# Plug-in Hybrid Electric Vehicle (PHEV)         July 06 2021              2021
# Battery Electric Vehicle (BEV)               August 26 2019              2019
# Battery Electric Vehicle (BEV)                 July 21 2022              2022
# Plug-in Hybrid Electric Vehicle (PHEV)         July 14 2018              2018
# Battery Electric Vehicle (BEV)              January 30 2020              2020
# Battery Electric Vehicle (BEV)             December 15 2021              2021
# Battery Electric Vehicle (BEV)            September 09 2022              2022
# Battery Electric Vehicle (BEV)                March 10 2021              2021
# Battery Electric Vehicle (BEV)              October 05 2017              2017
#
#                                               County          City  \
# Clean Alternative Fuel Vehicle Type
# Battery Electric Vehicle (BEV)                  King       SEATTLE
# Plug-in Hybrid Electric Vehicle (PHEV)  Grays Harbor  OCEAN SHORES
# Plug-in Hybrid Electric Vehicle (PHEV)          King        AUBURN
# Battery Electric Vehicle (BEV)                  King        RENTON
# Battery Electric Vehicle (BEV)                  King       SEATTLE
# Battery Electric Vehicle (BEV)                  King       SEATTLE
# Plug-in Hybrid Electric Vehicle (PHEV)          King       SEATTLE
# Battery Electric Vehicle (BEV)                  King     SAMMAMISH
# Battery Electric Vehicle (BEV)                  King     SAMMAMISH
# Plug-in Hybrid Electric Vehicle (PHEV)          King       SEATTLE
# Battery Electric Vehicle (BEV)                  King     SHORELINE
# Battery Electric Vehicle (BEV)                  King      ISSAQUAH
# Battery Electric Vehicle (BEV)               Spokane        CHENEY
# Battery Electric Vehicle (BEV)              Thurston       OLYMPIA
# Battery Electric Vehicle (BEV)                  King       REDMOND
#
#                                        State of Residence  Postal Code
# Clean Alternative Fuel Vehicle Type
# Battery Electric Vehicle (BEV)                         WA      98107.0
# Plug-in Hybrid Electric Vehicle (PHEV)                 WA      98569.0
# Plug-in Hybrid Electric Vehicle (PHEV)                 WA      98001.0
# Battery Electric Vehicle (BEV)                         WA      98056.0
# Battery Electric Vehicle (BEV)                         WA      98117.0
# Battery Electric Vehicle (BEV)                         WA      98117.0
# Plug-in Hybrid Electric Vehicle (PHEV)                 WA      98118.0
# Battery Electric Vehicle (BEV)                         WA      98074.0
# Battery Electric Vehicle (BEV)                         WA      98074.0
# Plug-in Hybrid Electric Vehicle (PHEV)                 WA      98122.0
# Battery Electric Vehicle (BEV)                         WA      98155.0
# Battery Electric Vehicle (BEV)                         WA      98029.0
# Battery Electric Vehicle (BEV)                         WA      99004.0
# Battery Electric Vehicle (BEV)                         WA      98503.0
# Battery Electric Vehicle (BEV)                         WA      98072.0

# %%
# delete duplicates
df.drop_duplicates(inplace=True)

# verifying that duplicates have been removed
len(df[df.duplicated()])
# Out:
# 0

# %%
# checking if there's null values in the dataset
df.isna().sum()
# Out:
# VIN (1-10)                   0
# DOL Vehicle ID               0
# Model Year                   0
# Make                         0
# Model                      205
# Vehicle Primary Use          0
# Electric Range               0
# Odometer Reading             0
# Odometer Code                0
# New or Used Vehicle          0
# Sale Price                   0
# Sale Date               476927
# Base MSRP                    0
# Transaction Type             0
# DOL Transaction Date         0
# Transaction Year             0
# County                      36
# City                        66
# State of Residence           1
# Postal Code                 44
# dtype: int64

# %% [markdown]
# 'Sale Date' column seems to be missing quite a bit of information. We have the dta of 'DOL transation date' which is the date when they register the car with the state. In general, the 'DOL transaction date' and the actual vehicle sale are very close (within a few weeks). The 'Sale date' here aren't too meaningful to us and seems to be missing a lot of data and so we are going to drop this colomun.

# %%
df.drop(['Sale Date'], axis=1, inplace=True) 
df.drop(['Base MSRP'], axis=1, inplace=True) # we have sale price already and so don't need this one
df.drop(['Transaction Year'], axis=1, inplace=True) # we have DOL transaction date also and so don't need this either

# %%
df.isna().sum() #checking the null one again after dropping the columns that are no longer needed
# Out:
# VIN (1-10)                0
# DOL Vehicle ID            0
# Model Year                0
# Make                      0
# Model                   205
# Vehicle Primary Use       0
# Electric Range            0
# Odometer Reading          0
# Odometer Code             0
# New or Used Vehicle       0
# Sale Price                0
# Transaction Type          0
# DOL Transaction Date      0
# County                   36
# City                     66
# State of Residence        1
# Postal Code              44
# dtype: int64

# %%
#dropping null values
df.dropna(subset=['Model'], inplace=True)
df.dropna(subset=['City'], inplace=True)
df.dropna(subset=['County'], inplace=True)
df.dropna(subset=['State of Residence'], inplace=True)
df.dropna(subset=['Postal Code'], inplace=True)
df.isna().sum()
# Out:
# VIN (1-10)              0
# DOL Vehicle ID          0
# Model Year              0
# Make                    0
# Model                   0
# Vehicle Primary Use     0
# Electric Range          0
# Odometer Reading        0
# Odometer Code           0
# New or Used Vehicle     0
# Sale Price              0
# Transaction Type        0
# DOL Transaction Date    0
# County                  0
# City                    0
# State of Residence      0
# Postal Code             0
# dtype: int64

# %% [markdown]
# <h5> The goal is this project is to focusing on the data analysis in Washington State. Therefore, we are only doing "State of Residence' = WA </h5>

# %%
df=df[df['State of Residence']=='WA']
from matplotlib import pyplot as plt
WA_States_EV_Car_Counts = df['County'].value_counts()/len(df['County'])*100 
WA_States_EV_Car_Counts.plot(kind= 'bar', figsize=(17,8)) # plots bar chart
plt.suptitle("Electric Vehicles Counts Per County in Washington State 2023") # title of plot
plt.xlabel('County In Washington State 2023') # label for x axis
plt.ylabel('Percent %'); # label for y axis

df['County'].value_counts()
# Out:
# King            368002
# Snohomish        74322
# Pierce           50991
# Clark            37365
# Kitsap           24104
# Thurston         22729
# Whatcom          17289
# Spokane          15575
# Benton            8003
# Island            7642
# Skagit            7233
# Clallam           4358
# Jefferson         4203
# San Juan          4098
# Chelan            3498
# Yakima            3252
# Mason             3250
# Cowlitz           3230
# Lewis             2604
# Grays Harbor      2306
# Franklin          2031
# Kittitas          1806
# Grant             1688
# Walla Walla       1629
# Douglas           1327
# Klickitat         1046
# Whitman           1017
# Stevens            805
# Okanogan           744
# Pacific            731
# Skamania           647
# Asotin             284
# Adams              191
# Pend Oreille       181
# Lincoln            161
# Wahkiakum          152
# Ferry              117
# Columbia            71
# Garfield            17
# Name: County, dtype: int64

# %%
df['DOL Transaction Date'] = pd.to_datetime(df['DOL Transaction Date'])
df.head()
# Out:
#                                      VIN (1-10)  DOL Vehicle ID  Model Year  \
# Clean Alternative Fuel Vehicle Type
# Battery Electric Vehicle (BEV)       WMEEJ9AA7E       349158127        2014
# Battery Electric Vehicle (BEV)       WMEEJ9AA7E       349158127        2014
# Battery Electric Vehicle (BEV)       WVWKR7AU7K       296928922        2019
# Battery Electric Vehicle (BEV)       WVWKR7AU7K       296928922        2019
# Battery Electric Vehicle (BEV)       WVWKR7AU7K       296928922        2019
#
#                                            Make                  Model  \
# Clean Alternative Fuel Vehicle Type
# Battery Electric Vehicle (BEV)            SMART  Fortwo Electric Drive
# Battery Electric Vehicle (BEV)            SMART  Fortwo Electric Drive
# Battery Electric Vehicle (BEV)       VOLKSWAGEN                 e-Golf
# Battery Electric Vehicle (BEV)       VOLKSWAGEN                 e-Golf
# Battery Electric Vehicle (BEV)       VOLKSWAGEN                 e-Golf
#
#                                     Vehicle Primary Use  Electric Range  \
# Clean Alternative Fuel Vehicle Type
# Battery Electric Vehicle (BEV)                Passenger              58
# Battery Electric Vehicle (BEV)                Passenger              58
# Battery Electric Vehicle (BEV)                Passenger             125
# Battery Electric Vehicle (BEV)                Passenger             125
# Battery Electric Vehicle (BEV)                Passenger             125
#
#                                     Odometer Reading  \
# Clean Alternative Fuel Vehicle Type
# Battery Electric Vehicle (BEV)                     0
# Battery Electric Vehicle (BEV)                     0
# Battery Electric Vehicle (BEV)                     5
# Battery Electric Vehicle (BEV)                     0
# Battery Electric Vehicle (BEV)                     0
#
#                                                                          Odometer Code  \
# Clean Alternative Fuel Vehicle Type
# Battery Electric Vehicle (BEV)       Odometer reading is not collected at time of r...
# Battery Electric Vehicle (BEV)       Odometer reading is not collected at time of r...
# Battery Electric Vehicle (BEV)                                          Actual Mileage
# Battery Electric Vehicle (BEV)       Odometer reading is not collected at time of r...
# Battery Electric Vehicle (BEV)       Odometer reading is not collected at time of r...
#
#                                     New or Used Vehicle Sale Price  \
# Clean Alternative Fuel Vehicle Type
# Battery Electric Vehicle (BEV)                     Used          0
# Battery Electric Vehicle (BEV)                     Used          0
# Battery Electric Vehicle (BEV)                      New     23,988
# Battery Electric Vehicle (BEV)                      New          0
# Battery Electric Vehicle (BEV)                     Used          0
#
#                                           Transaction Type  \
# Clean Alternative Fuel Vehicle Type
# Battery Electric Vehicle (BEV)        Registration Renewal
# Battery Electric Vehicle (BEV)        Registration Renewal
# Battery Electric Vehicle (BEV)              Original Title
# Battery Electric Vehicle (BEV)       Original Registration
# Battery Electric Vehicle (BEV)        Registration Renewal
#
#                                     DOL Transaction Date County     City  \
# Clean Alternative Fuel Vehicle Type
# Battery Electric Vehicle (BEV)                2021-06-07   King  SEATTLE
# Battery Electric Vehicle (BEV)                2022-06-06   King  SEATTLE
# Battery Electric Vehicle (BEV)                2019-11-06   King  REDMOND
# Battery Electric Vehicle (BEV)                2019-11-06   King  REDMOND
# Battery Electric Vehicle (BEV)                2020-10-05   King  REDMOND
#
#                                     State of Residence  Postal Code
# Clean Alternative Fuel Vehicle Type
# Battery Electric Vehicle (BEV)                      WA      98102.0
# Battery Electric Vehicle (BEV)                      WA      98102.0
# Battery Electric Vehicle (BEV)                      WA      98052.0
# Battery Electric Vehicle (BEV)                      WA      98052.0
# Battery Electric Vehicle (BEV)                      WA      98052.0

# %%
df['m/y'] = df['DOL Transaction Date'].dt.strftime("%m-%Y")

# %%
df.set_index('DOL Transaction Date', inplace=True)
df.head()
# Out:
#                       VIN (1-10)  DOL Vehicle ID  Model Year        Make  \
# DOL Transaction Date
# 2021-06-07            WMEEJ9AA7E       349158127        2014       SMART
# 2022-06-06            WMEEJ9AA7E       349158127        2014       SMART
# 2019-11-06            WVWKR7AU7K       296928922        2019  VOLKSWAGEN
# 2019-11-06            WVWKR7AU7K       296928922        2019  VOLKSWAGEN
# 2020-10-05            WVWKR7AU7K       296928922        2019  VOLKSWAGEN
#
#                                       Model Vehicle Primary Use  \
# DOL Transaction Date
# 2021-06-07            Fortwo Electric Drive           Passenger
# 2022-06-06            Fortwo Electric Drive           Passenger
# 2019-11-06                           e-Golf           Passenger
# 2019-11-06                           e-Golf           Passenger
# 2020-10-05                           e-Golf           Passenger
#
#                       Electric Range Odometer Reading  \
# DOL Transaction Date
# 2021-06-07                        58                0
# 2022-06-06                        58                0
# 2019-11-06                       125                5
# 2019-11-06                       125                0
# 2020-10-05                       125                0
#
#                                                           Odometer Code  \
# DOL Transaction Date
# 2021-06-07            Odometer reading is not collected at time of r...
# 2022-06-06            Odometer reading is not collected at time of r...
# 2019-11-06                                               Actual Mileage
# 2019-11-06            Odometer reading is not collected at time of r...
# 2020-10-05            Odometer reading is not collected at time of r...
#
#                      New or Used Vehicle Sale Price       Transaction Type  \
# DOL Transaction Date
# 2021-06-07                          Used          0   Registration Renewal
# 2022-06-06                          Used          0   Registration Renewal
# 2019-11-06                           New     23,988         Original Title
# 2019-11-06                           New          0  Original Registration
# 2020-10-05                          Used          0   Registration Renewal
#
#                      County     City State of Residence  Postal Code      m/y
# DOL Transaction Date
# 2021-06-07             King  SEATTLE                 WA      98102.0  06-2021
# 2022-06-06             King  SEATTLE                 WA      98102.0  06-2022
# 2019-11-06             King  REDMOND                 WA      98052.0  11-2019
# 2019-11-06             King  REDMOND                 WA      98052.0  11-2019
# 2020-10-05             King  REDMOND                 WA      98052.0  10-2020

# %%
df=df[(df['Transaction Type']=='Original Title') | 
      (df['Transaction Type']=='Transfer Title')]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 182187 entries, 2019-11-06 to 2014-11-05
# Data columns (total 17 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   VIN (1-10)           182187 non-null  object
#  1   DOL Vehicle ID       182187 non-null  int64
#  2   Model Year           182187 non-null  int64
#  3   Make                 182187 non-null  object
#  4   Model                182187 non-null  object
#  5   Vehicle Primary Use  182187 non-null  object
#  6   Electric Range       182187 non-null  int64
#  7   Odometer Reading     182187 non-null  object
#  8   Odometer Code        182187 non-null  object
#  9   New or Used Vehicle  182187 non-null  object
#  10  Sale Price           182187 non-null  object
#  11  Transaction Type     182187 non-null  object
#  12  County               182187 non-null  object
#  13  City                 182187 non-null  object
#  14  State of Residence   182187 non-null  object
#  15  Postal Code          182187 non-null  float64
#  16  m/y                  182187 non-null  object
# dtypes: float64(1), int64(3), object(13)
# memory usage: 25.0+ MB

# %%
county_dict = {}
for county in list(df['County'].unique()):
    county_dict[county] = df[
        (df['County']==county)&
        (df['Transaction Type']=='Original Title')
    ].resample('M').size().cumsum()

# %%
#filling null values created by resampling with 0's.
df_cumsum = pd.DataFrame(county_dict)
df_cumsum.fillna(0, inplace=True)

# %%
#summing each row to get monthly statewide total 
df_cumsum['State Total'] = df_cumsum.sum(axis=1)

# %%
df_cumsum = df_cumsum.reset_index()

# %%
#plotting statewide EV Count
import matplotlib.pyplot as plt
import seaborn as sns

fig, ax = plt.subplots(figsize=(15,10))
sns.lineplot(x='DOL Transaction Date', y='State Total', data=df_cumsum, ax=ax)
ax.set_xlabel('Date')
ax.set_ylabel('Total Electric Vehicle Count')
ax.set_title('Electric Vehicles on the Road in Washington State (2010-2023)')
ax.set_yticks(range(0,160000,10000))
plt.tight_layout()

# %% [markdown]
# <h4>We can see above that electric vehicles in Washington State have been increasing from 0 to 150000 over the past 13 years <h4>

# %%
df['County'].value_counts()
# Out:
# King            98332
# Snohomish       20374
# Pierce          14461
# Clark           10351
# Kitsap           6228
# Thurston         6215
# Spokane          4422
# Whatcom          4415
# Benton           2137
# Island           1882
# Skagit           1834
# Clallam          1041
# Jefferson         980
# San Juan          940
# Cowlitz           901
# Yakima            888
# Chelan            879
# Mason             817
# Lewis             654
# Franklin          600
# Grays Harbor      569
# Grant             463
# Kittitas          440
# Walla Walla       427
# Douglas           324
# Whitman           271
# Klickitat         259
# Stevens           206
# Pacific           190
# Skamania          183
# Okanogan          177
# Asotin             76
# Adams              58
# Pend Oreille       52
# Wahkiakum          44
# Lincoln            40
# Ferry              31
# Columbia           22
# Garfield            4
# Name: County, dtype: int64

# %%
#plotting county trends

all_counties = ['King', 'Snohomish', 'Pierce', 'Clark', 'Thurston', 'Kitsap', 'Whatcom', 'Spokane', 'Benton', 'Island', 'Skagit', 'Clallam', 'Jefferson', 'San Juan', 'Cowlitz', 'Yakima', 'Chelan', 'Mason', 'Lewis', 'Franklin', 'Grays Harbor', 'Grant', 'Kittitas', 'Walla Walla', 'Douglas', 'Whitman', 'Klickitat', 'Stevens', 'Pacific', 'Skamania', 'Okanogan', 'Asotin', 'Adams', 'Pend Oreille', 'Wahkiakum', 'Lincoln', 'Ferry', 'Columbia', 'Garfield'    ]
fig, ax = plt.subplots(figsize=(20,15))
for county in all_counties:
    sns.lineplot(x='DOL Transaction Date', y=county, data=df_cumsum, ax=ax, 
                 label=county)
ax.set_xlabel('Year')
ax.set_ylabel('EV Car Count')
ax.set_title('Total Electric Vehicle Count by County 2010 - 2023')
ax.legend()

# %%
def EV_car_model_purchased_by_county(df=df, top_n=10, county_list=all_counties):
    
    fig, ax = plt.subplots(figsize=(10, 60), nrows=len(county_list))
    
    for i, county in enumerate(county_list):
        df_county = df[(df['County']==county) & 
                       (df['Transaction Type']=='Original Title')]
        model_count_df = pd.DataFrame(df_county['Model'].value_counts()).reset_index()
        model_count_df.columns=['Model', 'Count']
        sns.barplot(x='Model', y='Count', data=model_count_df.head(top_n), 
                    ax=ax[i])
        ax[i].set_title(f'{county} County (2010-2023)')
    plt.tight_layout();

# %%
EV_car_model_purchased_by_county()

# %% [markdown]
# <h3> Above we can see Tesla, Leaf and Vblt are the top 3 most popular brand when it comes to EV car being purchased in Washington state </h3>

# %%
df_cumsum = df_cumsum.set_index('DOL Transaction Date').resample('M').asfreq()
df_cumsum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 157 entries, 2010-02-28 to 2023-02-28
# Freq: M
# Data columns (total 40 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   King          157 non-null    float64
#  1   Clark         157 non-null    float64
#  2   Thurston      157 non-null    float64
#  3   Kitsap        157 non-null    int64
#  4   Snohomish     157 non-null    float64
#  5   Jefferson     157 non-null    float64
#  6   Yakima        157 non-null    float64
#  7   Cowlitz       157 non-null    float64
#  8   Stevens       157 non-null    float64
#  9   Pierce        157 non-null    float64
#  10  Klickitat     157 non-null    float64
#  11  Kittitas      157 non-null    float64
#  12  Chelan        157 non-null    float64
#  13  Skagit        157 non-null    float64
#  14  Island        157 non-null    float64
#  15  Whatcom       157 non-null    float64
#  16  Whitman       157 non-null    float64
#  17  Grant         157 non-null    float64
#  18  Spokane       157 non-null    float64
#  19  San Juan      157 non-null    float64
#  20  Douglas       157 non-null    float64
#  21  Okanogan      157 non-null    float64
#  22  Walla Walla   157 non-null    float64
#  23  Clallam       157 non-null    float64
#  24  Mason         157 non-null    float64
#  25  Benton        157 non-null    float64
#  26  Franklin      157 non-null    float64
#  27  Grays Harbor  157 non-null    float64
#  28  Pacific       157 non-null    float64
#  29  Wahkiakum     157 non-null    float64
#  30  Ferry         157 non-null    float64
#  31  Skamania      157 non-null    float64
#  32  Lewis         157 non-null    float64
#  33  Pend Oreille  157 non-null    float64
#  34  Asotin        157 non-null    float64
#  35  Columbia      157 non-null    float64
#  36  Adams         157 non-null    float64
#  37  Lincoln       157 non-null    float64
#  38  Garfield      157 non-null    float64
#  39  State Total   157 non-null    float64
# dtypes: float64(39), int64(1)
# memory usage: 50.3 KB

# %%
def separate_data_by_county(county, df): 
    df_county = pd.DataFrame(df.loc[:, county])
    df_county.columns=["EV car counts"]
    df_county.head()
    return df_county

# %% [markdown]
# ## Modeling and Evaluation using ARIMA
# SARIMAX(Seasonal Auto-Regressive Integrated Moving Average with eXogenous factors) is an extension of the ARIMA class of models. We are using this to make predction to understand how many more EV cars will be on the road in the following county (King County, Snohomish, Pierce) for the next 10 years.

# %%
#separating all the county data with its EV car counts
county_information = {}
for county in all_counties:
    county_information[county] = {}
    county_information[county]['df']=separate_data_by_county(county, df_cumsum)

# %%
def get_prediction(model, df, test_data, county_name, plot=True):    
    #creating a df with the prediction information
    prediction_df = model.get_forecast(steps=len(test_data)*5).conf_int()
    prediction_df.columns = ['Lower Confidence Interval', 'Upper Confidence Interval']
    prediction_df['Predictions'] = model.get_forecast(steps=len(test_data)*5)\
    .predicted_mean
    #plotting
    if plot==True:
        with plt.style.context('seaborn-whitegrid'):
            fig, ax = plt.subplots(figsize=(20, 15))
            sns.lineplot(data=df, ax=ax)
            sns.lineplot(data=prediction_df, x=prediction_df.index, 
                         y='Predictions', color='red', ax=ax, 
                         label='Predicted Data', ls='--')
            ax.fill_between(prediction_df.index, 
                            y1=prediction_df['Lower Confidence Interval'], 
                            y2=prediction_df['Upper Confidence Interval'],
                            color = 'green', alpha=0.3, 
                            label='Confidence Interval')
            ax.set_xlabel('Year')
            ax.set_ylabel('Electric Vehicles on the Road')
            ax.set_title(f'Predicted Electric Vehicle Count for {county_name}')
            plt.show();
    return prediction_df

# %%
def train_test_split_ts (df, train_size, test_size):
    train_end_idx = int(round(len(df)*train_size,0))
    train_set = df.iloc[0:train_end_idx,:]["EV car counts"]
    test_set = df.iloc[train_end_idx:,:]["EV car counts"]
    return train_set, test_set

# %% [markdown]
# ## King County EV Car Count Future Prediction

# %%
#splitting dataset into train and test sets for validation
train_king, test_king = train_test_split_ts(county_information['King']['df'], 0.80, 0.20)

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
King_County_Model = SARIMAX(county_information['King']['df'], order=(1,1,0), 
                seasonal_order=(0,1,0,12), enforce_invertibility=False, 
                enforce_stationarity=False).fit()
print(King_County_Model.summary())
# Out:
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                      EV car counts   No. Observations:                  157
# Model:             SARIMAX(1, 1, 0)x(0, 1, 0, 12)   Log Likelihood                -974.746
# Date:                            Wed, 29 Mar 2023   AIC                           1953.491
# Time:                                    05:37:19   BIC                           1959.417
# Sample:                                02-28-2010   HQIC                          1955.899
#                                      - 02-28-2023
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.6758      0.058     11.577      0.000       0.561       0.790
# sigma2      4.877e+04   3345.779     14.577      0.000    4.22e+04    5.53e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                  10.15   Jarque-Bera (JB):                98.18
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):              39.06   Skew:                             0.70
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.81
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
df_king_preds = get_prediction(King_County_Model, county_information['King']['df'], test_king, 'King', plot=True)

# %% [markdown]
# ## Snohomish County EV Car Count Future Prediction

# %%
#splitting dataset into train and test sets for validation
train_Snohomish, test_Snohomish = train_test_split_ts(county_information['Snohomish']['df'], 0.80, 0.20)

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
Snohomish_County_Model = SARIMAX(county_information['Snohomish']['df'], order=(1,1,0), 
                seasonal_order=(0,1,0,12), enforce_invertibility=False, 
                enforce_stationarity=False).fit()
print(Snohomish_County_Model.summary())
# Out:
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                      EV car counts   No. Observations:                  157
# Model:             SARIMAX(1, 1, 0)x(0, 1, 0, 12)   Log Likelihood                -745.664
# Date:                            Wed, 29 Mar 2023   AIC                           1495.328
# Time:                                    05:37:20   BIC                           1501.254
# Sample:                                02-28-2010   HQIC                          1497.736
#                                      - 02-28-2023
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.7430      0.047     15.744      0.000       0.650       0.835
# sigma2      1980.2753    142.614     13.886      0.000    1700.756    2259.794
# ===================================================================================
# Ljung-Box (L1) (Q):                  10.67   Jarque-Bera (JB):                89.96
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):              25.39   Skew:                             1.11
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.19
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
df_Snohomish_preds = get_prediction(Snohomish_County_Model, county_information['Snohomish']['df'], test_Snohomish, 'Snohomish', plot=True)

# %% [markdown]
# ## Pierce EV Car Count Future Prediction

# %%
#splitting dataset into train and test sets for validation
train_Pierce, test_Pierce = train_test_split_ts(county_information['Pierce']['df'], 0.80, 0.20)

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
Pierce_County_Model = SARIMAX(county_information['Pierce']['df'], order=(1,1,0), 
                seasonal_order=(0,1,0,12), enforce_invertibility=False, 
                enforce_stationarity=False).fit()
print(Pierce_County_Model.summary())
# Out:
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                      EV car counts   No. Observations:                  157
# Model:             SARIMAX(1, 1, 0)x(0, 1, 0, 12)   Log Likelihood                -675.575
# Date:                            Wed, 29 Mar 2023   AIC                           1355.150
# Time:                                    05:37:21   BIC                           1361.076
# Sample:                                02-28-2010   HQIC                          1357.558
#                                      - 02-28-2023
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.7828      0.028     27.614      0.000       0.727       0.838
# sigma2       743.0225     51.246     14.499      0.000     642.583     843.462
# ===================================================================================
# Ljung-Box (L1) (Q):                  10.75   Jarque-Bera (JB):               106.04
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):              11.44   Skew:                             0.74
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.95
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# c:\users\queen\appdata\local\programs\python\python39\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
df_Pierce_preds = get_prediction(Pierce_County_Model, county_information['Pierce']['df'], test_Pierce, 'Pierce', plot=True)

# %% [markdown]
# ## Starbucks Locations Per County in WA State

# %%
# Import Starbucks store data into the notebook
## dataset was download from http://www.starbuckseverywhere.net/StoreOpeningDates.htm
import requests
import time
import pandas as pd
df_starbucks_stores=pd.read_csv('starbucks_In_WashingtonStates_March_2023.csv', index_col=0)
df_starbucks_stores['County'].value_counts() # Starbucks store per county
# Out:
# King             90
# Pierce           28
# Clark            25
# Snohomish        22
# Whatcom          14
# Spokane          12
# Thurston         12
# Kitsap            9
# Benton            6
# Yakima            5
# Cowlitz           3
# Whitman           2
# Mason             2
# Lewis             2
# Chelan            2
# Clallam           1
# Monroe            1
# Asotin            1
# Grays Harbor      1
# Grant             1
# Leavenworth       1
# Aberdeenshire     1
# Lancaster         1
# Franklin          1
# Adams             1
# Name: County, dtype: int64

# %%
from matplotlib import pyplot as plt

WA_States_Starbucks_Store_Counts =df_starbucks_stores['County'].value_counts()/len(df_starbucks_stores['County'])*100 
WA_States_Starbucks_Store_Counts.plot(kind= 'bar', figsize=(17,8)) # plots bar chart
plt.suptitle("Starbuck Store Per County in Washington State 2023") # title of plot
plt.xlabel('County In Washington State 2023') # label for x axis
plt.ylabel('Percent %'); # label for y axis

# %% [markdown]
# ## Existing EV Charger Per County in WA State

# %%
#importing the existing EV charger data into the notebook
## dataset was download from U.S Department of Energy https://afdc.energy.gov/stations/#/find/nearest
import requests
import time
import pandas as pd
df_existing_EV_stations=pd.read_csv('alt_fuel_stations.csv', index_col=0)

# %%
from uszipcode import SearchEngine
# Out:
# c:\users\queen\appdata\local\programs\python\python39\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
#Creating a dictionary that shows which county each zipcode is in
zipcodes_to_search = list(df_existing_EV_stations['ZIP'].unique())
sr = SearchEngine()
zip_map = {}
for zipcode in zipcodes_to_search:
    zipcode_object= sr.by_zipcode(zipcode)
    zip_map[zipcode] = zipcode_object
zip_map
# Out:
# {'98233': SimpleZipcode(zipcode='98233', zipcode_type='STANDARD', major_city='Burlington', post_office_city='Burlington, WA', common_city_list=['Burlington'], county='Skagit County', state='WA', lat=48.53, lng=-122.31, timezone='America/Los_Angeles', radius_in_miles=10.0, area_code_list='360', population=14871, population_density=439.0, land_area_in_sqmi=33.85, water_area_in_sqmi=0.26, housing_units=5897, occupied_housing_units=5522, median_home_value=232700, median_household_income=52906, bounds_west=-122.444478, bounds_east=-122.285302, bounds_north=48.620048, bounds_south=48.444658),
#  '98277': SimpleZipcode(zipcode='98277', zipcode_type='STANDARD', major_city='Oak Harbor', post_office_city='Oak Harbor, WA', common_city_list=['Oak Harbor'], county='Island County', state='WA', lat=48.32, lng=-122.63, timezone='America/Los_Angeles', radius_in_miles=12.0, area_code_list='360', population=37823, population_density=670.0, land_area_in_sqmi=56.42, water_area_in_sqmi=14.74, housing_units=16752, occupied_housing_units=15071, median_home_value=243400, median_household_income=53556, bounds_west=-122.768716, bounds_east=-122.496765, bounds_north=48.417855, bounds_south=48.230919),
#  '98901': SimpleZipcode(zipcode='98901', zipcode_type='STANDARD', major_city='Yakima', post_office_city='Yakima, WA', common_city_list=['Yakima', 'Union Gap'], county='Yakima County', state='WA', lat=46.72, lng=-120.41, timezone='America/Los_Angeles', radius_in_miles=15.0, area_code_list='509', population=30169, population_density=259.0, land_area_in_sqmi=116.65, water_area_in_sqmi=1.69, housing_units=10287, occupied_housing_units=9735, median_home_value=132700, median_household_income=35738, bounds_west=-120.55695, bounds_east=-120.255737, bounds_north=46.897656, bounds_south=46.547675),
#  '98296': SimpleZipcode(zipcode='98296', zipcode_type='STANDARD', major_city='Snohomish', post_office_city='Snohomish, WA', common_city_list=['Snohomish'], county='Snohomish County', state='WA', lat=47.85, lng=-122.09, timezone='America/Los_Angeles', radius_in_miles=9.0, area_code_list='360', population=27956, population_density=820.0, land_area_in_sqmi=34.08, water_area_in_sqmi=0.65, housing_units=9814, occupied_housing_units=9413, median_home_value=404200, median_household_income=109355, bounds_west=-122.187799, bounds_east=-122.012895, bounds_north=47.928318, bounds_south=47.77539),
#  '99141': SimpleZipcode(zipcode='99141', zipcode_type='STANDARD', major_city='Kettle Falls', post_office_city='Kettle Falls, WA', common_city_list=['Kettle Falls'], county='Stevens County', state='WA', lat=48.74, lng=-118.09, timezone='America/Los_Angeles', radius_in_miles=29.0, area_code_list='509', population=5240, population_density=10.0, land_area_in_sqmi=529.82, water_area_in_sqmi=27.21, housing_units=2722, occupied_housing_units=2285, median_home_value=167200, median_household_income=38662, bounds_west=-118.446628, bounds_east=-117.795999, bounds_north=49.000441, bounds_south=48.418263),
#  '99202': SimpleZipcode(zipcode='99202', zipcode_type='STANDARD', major_city='Spokane', post_office_city='Spokane, WA', common_city_list=['Spokane'], county='Spokane County', state='WA', lat=47.65, lng=-117.37, timezone='America/Los_Angeles', radius_in_miles=2.0, area_code_list='509', population=21580, population_density=3514.0, land_area_in_sqmi=6.14, water_area_in_sqmi=0.1, housing_units=8159, occupied_housing_units=7426, median_home_value=138200, median_household_income=32859, bounds_west=-117.413433, bounds_east=-117.344298, bounds_north=47.673668, bounds_south=47.639882),
#  '98271': SimpleZipcode(zipcode='98271', zipcode_type='STANDARD', major_city='Marysville', post_office_city='Marysville, WA', common_city_list=['Marysville', 'Tulalip'], county='Snohomish County', state='WA', lat=48.09, lng=-122.24, timezone='America/Los_Angeles', radius_in_miles=7.0, area_code_list='360', population=27184, population_density=583.0, land_area_in_sqmi=46.6, water_area_in_sqmi=4.97, housing_units=10496, occupied_housing_units=9697, median_home_value=234800, median_household_income=66188, bounds_west=-122.368688, bounds_east=-122.111844, bounds_north=48.167107, bounds_south=48.024518),
#  '98264': SimpleZipcode(zipcode='98264', zipcode_type='STANDARD', major_city='Lynden', post_office_city='Lynden, WA', common_city_list=['Lynden'], county='Whatcom County', state='WA', lat=48.95, lng=-122.43, timezone='America/Los_Angeles', radius_in_miles=8.0, area_code_list='360', population=18893, population_density=331.0, land_area_in_sqmi=57.05, water_area_in_sqmi=0.99, housing_units=7254, occupied_housing_units=6889, median_home_value=279000, median_household_income=57026, bounds_west=-122.574382, bounds_east=-122.329592, bounds_north=49.002457, bounds_south=48.858872),
#  '98028': SimpleZipcode(zipcode='98028', zipcode_type='STANDARD', major_city='Kenmore', post_office_city='Kenmore, WA', common_city_list=['Kenmore', 'Bothell'], county='King County', state='WA', lat=47.75, lng=-122.24, timezone='America/Los_Angeles', radius_in_miles=3.0, area_code_list='425', population=20419, population_density=3606.0, land_area_in_sqmi=5.66, water_area_in_sqmi=0.72, housing_units=8566, occupied_housing_units=7981, median_home_value=386200, median_household_income=82448, bounds_west=-122.276137, bounds_east=-122.218452, bounds_north=47.777073, bounds_south=47.731771),
#  '98107': SimpleZipcode(zipcode='98107', zipcode_type='STANDARD', major_city='Seattle', post_office_city='Seattle, WA', common_city_list=['Seattle'], county='King County', state='WA', lat=47.67, lng=-122.38, timezone='America/Los_Angeles', radius_in_miles=2.0, area_code_list='206', population=21147, population_density=9602.0, land_area_in_sqmi=2.2, water_area_in_sqmi=0.27, housing_units=12360, occupied_housing_units=11284, median_home_value=447700, median_household_income=67566, bounds_west=-122.414259, bounds_east=-122.354463, bounds_north=47.676919, bounds_south=47.649932),
#  '98118': SimpleZipcode(zipcode='98118', zipcode_type='STANDARD', major_city='Seattle', post_office_city='Seattle, WA', common_city_list=['Seattle'], county='King County', state='WA', lat=47.54, lng=-122.27, timezone='America/Los_Angeles', radius_in_miles=4.0, area_code_list='206', population=42731, population_density=6841.0, land_area_in_sqmi=6.25, water_area_in_sqmi=2.64, housing_units=16162, occupied_housing_units=15127, median_home_value=350700, median_household_income=52276, bounds_west=-122.296187, bounds_east=-122.23807, bounds_north=47.575921, bounds_south=47.508604),
#  '98133': SimpleZipcode(zipcode='98133', zipcode_type='STANDARD', major_city='Seattle', post_office_city='Seattle, WA', common_city_list=['Seattle', 'Shoreline'], county='King County', state='WA', lat=47.73, lng=-122.34, timezone='America/Los_Angeles', radius_in_miles=4.0, area_code_list='206,425', population=44555, population_density=6279.0, land_area_in_sqmi=7.1, water_area_in_sqmi=0.07, housing_units=21903, occupied_housing_units=20180, median_home_value=326400, median_household_income=51499, bounds_west=-122.370936, bounds_east=-122.328181, bounds_north=47.777794, bounds_south=47.700867),
#  '98198': SimpleZipcode(zipcode='98198', zipcode_type='STANDARD', major_city='Seattle', post_office_city='Seattle, WA', common_city_list=['Seattle', 'Des Moines', 'Normandy Park', 'Seatac'], county='King County', state='WA', lat=47.38, lng=-122.31, timezone='America/Los_Angeles', radius_in_miles=5.0, area_code_list='206,253', population=34584, population_density=4441.0, land_area_in_sqmi=7.79, water_area_in_sqmi=0.9, housing_units=14328, occupied_housing_units=13106, median_home_value=258500, median_household_income=56364, bounds_west=-122.343594, bounds_east=-122.280813, bounds_north=47.423776, bounds_south=47.340397),
#  '98203': SimpleZipcode(zipcode='98203', zipcode_type='STANDARD', major_city='Everett', post_office_city='Everett, WA', common_city_list=['Everett'], county='Snohomish County', state='WA', lat=47.94, lng=-122.24, timezone='America/Los_Angeles', radius_in_miles=4.0, area_code_list='425', population=34354, population_density=3209.0, land_area_in_sqmi=10.7, water_area_in_sqmi=0.87, housing_units=14245, occupied_housing_units=13425, median_home_value=251900, median_household_income=57119, bounds_west=-122.291664, bounds_east=-122.186644, bounds_north=47.970909, bounds_south=47.918975),
#  '98444': SimpleZipcode(zipcode='98444', zipcode_type='STANDARD', major_city='Tacoma', post_office_city='Tacoma, WA', common_city_list=['Tacoma', 'Parkland'], county='Pierce County', state='WA', lat=47.15, lng=-122.44, timezone='America/Los_Angeles', radius_in_miles=3.0, area_code_list='253', population=33956, population_density=5047.0, land_area_in_sqmi=6.73, water_area_in_sqmi=0.05, housing_units=13520, occupied_housing_units=12518, median_home_value=175800, median_household_income=39846, bounds_west=-122.472476, bounds_east=-122.426134, bounds_north=47.184692, bounds_south=47.116003),
#  '98661': SimpleZipcode(zipcode='98661', zipcode_type='STANDARD', major_city='Vancouver', post_office_city='Vancouver, WA', common_city_list=['Vancouver'], county='Clark County', state='WA', lat=45.64, lng=-122.63, timezone='America/Los_Angeles', radius_in_miles=3.0, area_code_list='360', population=41740, population_density=3929.0, land_area_in_sqmi=10.62, water_area_in_sqmi=0.71, housing_units=18556, occupied_housing_units=17174, median_home_value=193500, median_household_income=39665, bounds_west=-122.675332, bounds_east=-122.591521, bounds_north=45.678836, bounds_south=45.608139),
#  '99218': SimpleZipcode(zipcode='99218', zipcode_type='STANDARD', major_city='Spokane', post_office_city='Spokane, WA', common_city_list=['Spokane'], county='Spokane County', state='WA', lat=47.75, lng=-117.43, timezone='America/Los_Angeles', radius_in_miles=4.0, area_code_list='509', population=15531, population_density=2124.0, land_area_in_sqmi=7.31, water_area_in_sqmi=0.0, housing_units=6030, occupied_housing_units=5645, median_home_value=207100, median_household_income=45983, bounds_west=-117.453967, bounds_east=-117.367562, bounds_north=47.784528, bounds_south=47.73662),
#  '99301': SimpleZipcode(zipcode='99301', zipcode_type='STANDARD', major_city='Pasco', post_office_city='Pasco, WA', common_city_list=['Pasco'], county='Franklin County', state='WA', lat=46.41, lng=-118.9, timezone='America/Los_Angeles', radius_in_miles=37.0, area_code_list='509', population=68191, population_density=147.0, land_area_in_sqmi=464.98, water_area_in_sqmi=13.75, housing_units=21697, occupied_housing_units=20738, median_home_value=162600, median_household_income=56098, bounds_west=-119.270504, bounds_east=-118.534738, bounds_north=46.637906, bounds_south=46.192856),
#  '98188': SimpleZipcode(zipcode='98188', zipcode_type='STANDARD', major_city='Seattle', post_office_city='Seattle, WA', common_city_list=['Seattle', 'Seatac', 'Tukwila'], county='King County', state='WA', lat=47.44, lng=-122.28, timezone='America/Los_Angeles', radius_in_miles=3.0, area_code_list='425,206,253', population=23111, population_density=3062.0, land_area_in_sqmi=7.55, water_area_in_sqmi=0.29, housing_units=9959, occupied_housing_units=9263, median_home_value=226800, median_household_income=40815, bounds_west=-122.313135, bounds_east=-122.239208, bounds_north=47.475122, bounds_south=47.420369),
#  '99354': SimpleZipcode(zipcode='99354', zipcode_type='STANDARD', major_city='Richland', post_office_city='Richland, WA', common_city_list=['Richland'], county='Benton County', state='WA', lat=46.35, lng=-119.32, timezone='America/Los_Angeles', radius_in_miles=22.0, area_code_list='509', population=21343, population_density=1051.0, land_area_in_sqmi=20.31, water_area_in_sqmi=0.08, housing_units=9384, occupied_housing_units=8840, median_home_value=177400, median_household_income=62689, bounds_west=-119.393781, bounds_east=-119.259497, bounds_north=46.367462, bounds_south=46.278954),
#  '98503': SimpleZipcode(zipcode='98503', zipcode_type='STANDARD', major_city='Lacey', post_office_city='Lacey, WA', common_city_list=['Lacey', 'Olympia'], county='Thurston County', state='WA', lat=47.02, lng=-122.79, timezone='America/Los_Angeles', radius_in_miles=3.0, area_code_list='360', population=36611, population_density=3244.0, land_area_in_sqmi=11.28, water_area_in_sqmi=0.97, housing_units=15998, occupied_housing_units=14764, median_home_value=214800, median_household_income=58112, bounds_west=-122.839224, bounds_east=-122.749043, bounds_north=47.059856, bounds_south=46.99619),
#  '98108': SimpleZipcode(zipcode='98108', zipcode_type='STANDARD', major_city='Seattle', post_office_city='Seattle, WA', common_city_list=['Seattle', 'Tukwila'], county='King County', state='WA', lat=47.54, lng=-122.31, timezone='America/Los_Angeles', radius_in_miles=3.0, area_code_list='206', population=22374, population_density=2989.0, land_area_in_sqmi=7.48, water_area_in_sqmi=0.37, housing_units=8194, occupied_housing_units=7643, median_home_value=326500, median_household_income=52232, bounds_west=-122.342737, bounds_east=-122.289183, bounds_north=47.572568, bounds_south=47.510683),
#  '98631': SimpleZipcode(zipcode='98631', zipcode_type='STANDARD', major_city='Long Beach', post_office_city='Long Beach, WA', common_city_list=['Long Beach'], county='Pacific County', state='WA', lat=46.39, lng=-124.03, timezone='America/Los_Angeles', radius_in_miles=6.0, area_code_list='360', population=3243, population_density=209.0, land_area_in_sqmi=15.54, water_area_in_sqmi=10.77, housing_units=3201, occupied_housing_units=1613, median_home_value=178100, median_household_income=44116, bounds_west=-124.067854, bounds_east=-123.973453, bounds_north=46.464883, bounds_south=46.325812),
#  '99252': SimpleZipcode(zipcode='99252', zipcode_type='UNIQUE', major_city='Spokane', post_office_city=None, common_city_list=['Spokane'], county='Spokane County', state='WA', lat=47.65, lng=-117.37, timezone='America/Los_Angeles', radius_in_miles=None, area_code_list='509', population=None, population_density=None, land_area_in_sqmi=None, water_area_in_sqmi=None, housing_units=None, occupied_housing_units=None, median_home_value=None, median_household_income=None, bounds_west=None, bounds_east=None, bounds_north=None, bounds_south=None),
#  '99201': SimpleZipcode(zipcode='99201', zipcode_type='STANDARD', major_city='Spokane', post_office_city='Spokane, WA', common_city_list=['Spokane'], county='Spokane County', state='WA', lat=47.66, lng=-117.43, timezone='America/Los_Angeles', radius_in_miles=2.0, area_code_list='509', population=13342, population_density=4445.0, land_area_in_sqmi=3.0, water_area_in_sqmi=0.19, housing_units=7858, occupied_housing_units=6804, median_home_value=142100, median_household_income=24532, bounds_west=-117.463036, bounds_east=-117.411058, bounds_north=47.680756, bounds_south=47.648674),
#  '98004': SimpleZipcode(zipcode='98004', zipcode_type='STANDARD', major_city='Bellevue', post_office_city='Bellevue, WA', common_city_list=['Bellevue', 'Beaux Arts', 'Clyde Hill', 'Hunts Point', 'Yar...'], county='King County', state='WA', lat=47.61, lng=-122.21, timezone='America/Los_Angeles', radius_in_miles=4.0, area_code_list='425', population=27946, population_density=3977.0, land_area_in_sqmi=7.03, water_area_in_sqmi=1.61, housing_units=16568, occupied_housing_units=13320, median_home_value=723300, median_household_income=93521, bounds_west=-122.235128, bounds_east=-122.181229, bounds_north=47.657588, bounds_south=47.574044),
#  '98505': SimpleZipcode(zipcode='98505', zipcode_type='UNIQUE', major_city='Olympia', post_office_city=None, common_city_list=['Olympia'], county='Thurston County', state='WA', lat=47.07, lng=-122.98, timezone='America/Los_Angeles', radius_in_miles=None, area_code_list='360', population=None, population_density=None, land_area_in_sqmi=None, water_area_in_sqmi=None, housing_units=None, occupied_housing_units=None, median_home_value=None, median_household_income=None, bounds_west=None, bounds_east=None, bounds_north=None, bounds_south=None),
#  '98027': SimpleZipcode(zipcode='98027', zipcode_type='STANDARD', major_city='Issaquah', post_office_city='Issaquah, WA', common_city_list=['Issaquah'], county='King County', state='WA', lat=47.5, lng=-122.0, timezone='America/Los_Angeles', radius_in_miles=8.0, area_code_list='425', population=26141, population_density=469.0, land_area_in_sqmi=55.79, water_area_in_sqmi=1.13, housing_units=11248, occupied_housing_units=10454, median_home_value=478800, median_household_income=100644, bounds_west=-122.129535, bounds_east=-121.883425, bounds_north=47.587777, bounds_south=47.426729),
#  '98011': SimpleZipcode(zipcode='98011', zipcode_type='STANDARD', major_city='Bothell', post_office_city='Bothell, WA', common_city_list=['Bothell'], county='King County', state='WA', lat=47.74, lng=-122.2, timezone='America/Los_Angeles', radius_in_miles=2.0, area_code_list='425', population=29212, population_density=3569.0, land_area_in_sqmi=8.19, water_area_in_sqmi=0.0, housing_units=12646, occupied_housing_units=11905, median_home_value=351000, median_household_income=71720, bounds_west=-122.245212, bounds_east=-122.163526, bounds_north=47.776637, bounds_south=47.724255),
#  '98052': SimpleZipcode(zipcode='98052', zipcode_type='STANDARD', major_city='Redmond', post_office_city='Redmond, WA', common_city_list=['Redmond'], county='King County', state='WA', lat=47.68, lng=-122.12, timezone='America/Los_Angeles', radius_in_miles=5.0, area_code_list='206,425', population=58442, population_density=2908.0, land_area_in_sqmi=20.1, water_area_in_sqmi=0.83, housing_units=25674, occupied_housing_units=24008, median_home_value=465200, median_household_income=99192, bounds_west=-122.164898, bounds_east=-122.077888, bounds_north=47.733618, bounds_south=47.627183),
#  '98229': SimpleZipcode(zipcode='98229', zipcode_type='STANDARD', major_city='Bellingham', post_office_city='Bellingham, WA', common_city_list=['Bellingham'], county='Whatcom County', state='WA', lat=48.68, lng=-122.41, timezone='America/Los_Angeles', radius_in_miles=8.0, area_code_list='360', population=30321, population_density=617.0, land_area_in_sqmi=49.14, water_area_in_sqmi=5.11, housing_units=13600, occupied_housing_units=12493, median_home_value=302500, median_household_income=59394, bounds_west=-122.512104, bounds_east=-122.303849, bounds_north=48.763026, bounds_south=48.609316),
#  '98312': SimpleZipcode(zipcode='98312', zipcode_type='STANDARD', major_city='Bremerton', post_office_city='Bremerton, WA', common_city_list=['Bremerton'], county='Kitsap County', state='WA', lat=47.57, lng=-122.75, timezone='America/Los_Angeles', radius_in_miles=10.0, area_code_list='360', population=30203, population_density=491.0, land_area_in_sqmi=61.46, water_area_in_sqmi=5.83, housing_units=14105, occupied_housing_units=12253, median_home_value=222900, median_household_income=55717, bounds_west=-122.871119, bounds_east=-122.644467, bounds_north=47.658145, bounds_south=47.484004),
#  '98148': SimpleZipcode(zipcode='98148', zipcode_type='STANDARD', major_city='Seattle', post_office_city='Seattle, WA', common_city_list=['Seattle', 'Burien', 'Des Moines', 'Normandy Park', 'Seata...'], county='King County', state='WA', lat=47.44, lng=-122.32, timezone='America/Los_Angeles', radius_in_miles=2.0, area_code_list='206,253', population=10010, population_density=3194.0, land_area_in_sqmi=3.13, water_area_in_sqmi=0.0, housing_units=4588, occupied_housing_units=4230, median_home_value=255900, median_household_income=45424, bounds_west=-122.340575, bounds_east=-122.3046, bounds_north=47.470438, bounds_south=47.422758),
#  '98026': SimpleZipcode(zipcode='98026', zipcode_type='STANDARD', major_city='Edmonds', post_office_city='Edmonds, WA', common_city_list=['Edmonds'], county='Snohomish County', state='WA', lat=47.84, lng=-122.33, timezone='America/Los_Angeles', radius_in_miles=6.0, area_code_list='425', population=35921, population_density=3852.0, land_area_in_sqmi=9.33, water_area_in_sqmi=1.15, housing_units=15039, occupied_housing_units=14373, median_home_value=344300, median_household_income=73220, bounds_west=-122.363975, bounds_east=-122.293235, bounds_north=47.900066, bounds_south=47.777595),
#  '98502': SimpleZipcode(zipcode='98502', zipcode_type='STANDARD', major_city='Olympia', post_office_city='Olympia, WA', common_city_list=['Olympia'], county='Thurston County', state='WA', lat=47.1, lng=-123.06, timezone='America/Los_Angeles', radius_in_miles=10.0, area_code_list='360', population=30491, population_density=561.0, land_area_in_sqmi=54.37, water_area_in_sqmi=16.75, housing_units=13997, occupied_housing_units=12637, median_home_value=304000, median_household_income=60837, bounds_west=-123.202066, bounds_east=-122.903375, bounds_north=47.190246, bounds_south=47.021096),
#  '98362': SimpleZipcode(zipcode='98362', zipcode_type='STANDARD', major_city='Port Angeles', post_office_city='Port Angeles, WA', common_city_list=['Port Angeles'], county='Clallam County', state='WA', lat=47.99, lng=-123.25, timezone='America/Los_Angeles', radius_in_miles=14.0, area_code_list='360', population=22230, population_density=101.0, land_area_in_sqmi=219.04, water_area_in_sqmi=0.07, housing_units=10915, occupied_housing_units=9961, median_home_value=221300, median_household_income=43827, bounds_west=-123.528985, bounds_east=-123.157382, bounds_north=48.125418, bounds_south=47.866873),
#  '98371': SimpleZipcode(zipcode='98371', zipcode_type='STANDARD', major_city='Puyallup', post_office_city='Puyallup, WA', common_city_list=['Puyallup', 'Edgewood'], county='Pierce County', state='WA', lat=47.19, lng=-122.33, timezone='America/Los_Angeles', radius_in_miles=4.0, area_code_list='253', population=20468, population_density=1775.0, land_area_in_sqmi=11.53, water_area_in_sqmi=0.08, housing_units=8867, occupied_housing_units=8265, median_home_value=265500, median_household_income=64335, bounds_west=-122.362857, bounds_east=-122.288923, bounds_north=47.243583, bounds_south=47.166524),
#  '98058': SimpleZipcode(zipcode='98058', zipcode_type='STANDARD', major_city='Renton', post_office_city='Renton, WA', common_city_list=['Renton'], county='King County', state='WA', lat=47.43, lng=-122.11, timezone='America/Los_Angeles', radius_in_miles=6.0, area_code_list='425', population=41938, population_density=2215.0, land_area_in_sqmi=18.93, water_area_in_sqmi=0.83, housing_units=16120, occupied_housing_units=15395, median_home_value=302200, median_household_income=77780, bounds_west=-122.186581, bounds_east=-122.05075, bounds_north=47.477898, bounds_south=47.389956),
#  '99212': SimpleZipcode(zipcode='99212', zipcode_type='STANDARD', major_city='Spokane', post_office_city='Spokane, WA', common_city_list=['Spokane', 'Millwood', 'Spokane Valley', 'Spokane Vly'], county='Spokane County', state='WA', lat=47.65, lng=-117.31, timezone='America/Los_Angeles', radius_in_miles=5.0, area_code_list='509', population=19197, population_density=1581.0, land_area_in_sqmi=12.14, water_area_in_sqmi=0.14, housing_units=8700, occupied_housing_units=8139, median_home_value=157000, median_household_income=52161, bounds_west=-117.347048, bounds_east=-117.281116, bounds_north=47.713805, bounds_south=47.620745),
#  '98409': SimpleZipcode(zipcode='98409', zipcode_type='STANDARD', major_city='Tacoma', post_office_city='Tacoma, WA', common_city_list=['Tacoma', 'Lakewood'], county='Pierce County', state='WA', lat=47.21, lng=-122.47, timezone='America/Los_Angeles', radius_in_miles=3.0, area_code_list='253', population=22989, population_density=3234.0, land_area_in_sqmi=7.11, water_area_in_sqmi=0.01, housing_units=9992, occupied_housing_units=8993, median_home_value=166700, median_household_income=46886, bounds_west=-122.505269, bounds_east=-122.440154, bounds_north=47.243632, bounds_south=47.184653),
#  '98662': SimpleZipcode(zipcode='98662', zipcode_type='STANDARD', major_city='Vancouver', post_office_city='Vancouver, WA', common_city_list=['Vancouver'], county='Clark County', state='WA', lat=45.68, lng=-122.57, timezone='America/Los_Angeles', radius_in_miles=5.0, area_code_list='360', population=31644, population_density=2458.0, land_area_in_sqmi=12.87, water_area_in_sqmi=0.0, housing_units=12331, occupied_housing_units=11761, median_home_value=200800, median_household_income=55986, bounds_west=-122.602233, bounds_east=-122.548809, bounds_north=45.747847, bounds_south=45.639427),
#  '99362': SimpleZipcode(zipcode='99362', zipcode_type='STANDARD', major_city='Walla Walla', post_office_city='Walla Walla, WA', common_city_list=['Walla Walla'], county='Walla Walla County', state='WA', lat=46.11, lng=-118.3, timezone='America/Los_Angeles', radius_in_miles=21.0, area_code_list='509', population=41056, population_density=128.0, land_area_in_sqmi=320.62, water_area_in_sqmi=0.12, housing_units=16264, occupied_housing_units=15013, median_home_value=205900, median_household_income=46605, bounds_west=-118.591469, bounds_east=-117.977732, bounds_north=46.294035, bounds_south=45.92122),
#  '98168': SimpleZipcode(zipcode='98168', zipcode_type='STANDARD', major_city='Seattle', post_office_city='Seattle, WA', common_city_list=['Seattle', 'Burien', 'Seatac', 'Tukwila'], county='King County', state='WA', lat=47.48, lng=-122.29, timezone='America/Los_Angeles', radius_in_miles=3.0, area_code_list='253,425,206', population=33734, population_density=3794.0, land_area_in_sqmi=8.89, water_area_in_sqmi=0.16, housing_units=12541, occupied_housing_units=11678, median_home_value=240000, median_household_income=49233, bounds_west=-122.335332, bounds_east=-122.251569, bounds_north=47.515648, bounds_south=47.462962),
#  '98006': SimpleZipcode(zipcode='98006', zipcode_type='STANDARD', major_city='Bellevue', post_office_city='Bellevue, WA', common_city_list=['Bellevue', 'Issaquah'], county='King County', state='WA', lat=47.55, lng=-122.14, timezone='America/Los_Angeles', radius_in_miles=3.0, area_code_list='425', population=36364, population_density=3402.0, land_area_in_sqmi=10.69, water_area_in_sqmi=0.75, housing_units=13891, occupied_housing_units=13288, median_home_value=574000, median_household_income=110290, bounds_west=-122.202007, bounds_east=-122.099107, bounds_north=47.580251, bounds_south=47.52482),
#  '98075': SimpleZipcode(zipcode='98075', zipcode_type='STANDARD', major_city='Sammamish', post_office_city='Sammamish, WA', common_city_list=['Sammamish', 'Issaquah'], county='King County', state='WA', lat=47.58, lng=-122.03, timezone='America/Los_Angeles', radius_in_miles=5.0, area_code_list='425', population=20715, population_density=2185.0, land_area_in_sqmi=9.48, water_area_in_sqmi=1.63, housing_units=7005, occupied_housing_units=6733, median_home_value=614100, median_household_income=142926, bounds_west=-122.098001, bounds_east=-121.970427, bounds_north=47.602915, bounds_south=47.558959),
#  '98032': SimpleZipcode(zipcode='98032', zipcode_type='STANDARD', major_city='Kent', post_office_city='Kent, WA', common_city_list=['Kent'], county='King County', state='WA', lat=47.39, lng=-122.26, timezone='America/Los_Angeles', radius_in_miles=5.0, area_code_list='253,425', population=33853, population_density=2024.0, land_area_in_sqmi=16.72, water_area_in_sqmi=0.29, housing_units=14451, occupied_housing_units=13393, median_home_value=234700, median_household_income=48853, bounds_west=-122.309417, bounds_east=-122.217459, bounds_north=47.441233, bounds_south=47.34633),
#  '98055': SimpleZipcode(zipcode='98055', zipcode_type='STANDARD', major_city='Renton', post_office_city='Renton, WA', common_city_list=['Renton'], county='King County', state='WA', lat=47.46, lng=-122.21, timezone='America/Los_Angeles', radius_in_miles=3.0, area_code_list='425', population=21904, population_density=4585.0, land_area_in_sqmi=4.78, water_area_in_sqmi=0.1, housing_units=9498, occupied_housing_units=8786, median_home_value=266100, median_household_income=66461, bounds_west=-122.220274, bounds_east=-122.183631, bounds_north=47.478729, bounds_south=47.420909),
#  '98057': SimpleZipcode(zipcode='98057', zipcode_type='STANDARD', major_city='Renton', post_office_city='Renton, WA', common_city_list=['Renton'], county='King County', state='WA', lat=47.47, lng=-122.22, timezone='America/Los_Angeles', radius_in_miles=3.0, area_code_list='425', population=10613, population_density=1742.0, land_area_in_sqmi=6.09, water_area_in_sqmi=0.07, housing_units=6049, occupied_housing_units=5127, median_home_value=256900, median_household_income=43339, bounds_west=-122.259227, bounds_east=-122.175467, bounds_north=47.502673, bounds_south=47.441122),
#  '98402': SimpleZipcode(zipcode='98402', zipcode_type='STANDARD', major_city='Tacoma', post_office_city='Tacoma, WA', common_city_list=['Tacoma'], county='Pierce County', state='WA', lat=47.26, lng=-122.44, timezone='America/Los_Angeles', radius_in_miles=4.0, area_code_list='253', population=6356, population_density=6748.0, land_area_in_sqmi=0.94, water_area_in_sqmi=0.22, housing_units=3933, occupied_housing_units=3286, median_home_value=260200, median_household_income=31500, bounds_west=-122.447849, bounds_east=-122.430824, bounds_north=47.268046, bounds_south=47.231413),
#  '98104': SimpleZipcode(zipcode='98104', zipcode_type='STANDARD', major_city='Seattle', post_office_city='Seattle, WA', common_city_list=['Seattle'], county='King County', state='WA', lat=47.6, lng=-122.32, timezone='America/Los_Angeles', radius_in_miles=1.0, area_code_list='206,253,360,425', population=13095, population_density=16899.0, land_area_in_sqmi=0.77, water_area_in_sqmi=0.1, housing_units=7711, occupied_housing_units=6749, median_home_value=392000, median_household_income=26637, bounds_west=-122.345442, bounds_east=-122.316783, bounds_north=47.612157, bounds_south=47.592403),
#  '98109': SimpleZipcode(zipcode='98109', zipcode_type='STANDARD', major_city='Seattle', post_office_city='Seattle, WA', common_city_list=['Seattle'], county='King County', state='WA', lat=47.63, lng=-122.34, timezone='America/Los_Angeles', radius_in_miles=2.0, area_code_list='425,206', population=20715, population_density=10361.0, land_area_in_sqmi=2.0, water_area_in_sqmi=0.42, housing_units=13906, occupied_housing_units=12419, median_home_value=451400, median_household_income=77034, bounds_west=-122.360874, bounds_east=-122.324057, bounds_north=47.65292, bounds_south=47.617698),
#  '98272': SimpleZipcode(zipcode='98272', zipcode_type='STANDARD', major_city='Monroe', post_office_city='Monroe, WA', common_city_list=['Monroe'], county='Snohomish County', state='WA', lat=47.87, lng=-121.88, timezone='America/Los_Angeles', radius_in_miles=14.0, area_code_list='360', population=27942, population_density=256.0, land_area_in_sqmi=109.28, water_area_in_sqmi=0.77, housing_units=9398, occupied_housing_units=8822, median_home_value=282900, median_household_income=78070, bounds_west=-122.047575, bounds_east=-121.711329, bounds_north=47.965248, bounds_south=47.775284),
#  '98283': SimpleZipcode(zipcode='98283', zipcode_type='STANDARD', major_city='Rockport', post_office_city='Rockport, WA', common_city_list=['Rockport'], county='Skagit County', state='WA', lat=48.8, lng=-121.26, timezone='America/Los_Angeles', radius_in_miles=11.0, area_code_list='360', population=434, population_density=1.0, land_area_in_sqmi=547.9, water_area_in_sqmi=26.87, housing_units=297, occupied_housing_units=205, median_home_value=168700, median_household_income=59083, bounds_west=-121.63006, bounds_east=-120.95884, bounds_north=49.001412, bounds_south=48.430183),
#  '98684': SimpleZipcode(zipcode='98684', zipcode_type='STANDARD', major_city='Vancouver', post_office_city='Vancouver, WA', common_city_list=['Vancouver'], county='Clark County', state='WA', lat=45.63, lng=-122.52, timezone='America/Los_Angeles', radius_in_miles=3.0, area_code_list='360', population=26968, population_density=3867.0, land_area_in_sqmi=6.97, water_area_in_sqmi=0.0, housing_units=10316, occupied_housing_units=9808, median_home_value=216300, median_household_income=58549, bounds_west=-122.56314, bounds_east=-122.45684, bounds_north=45.643628, bounds_south=45.614666),
#  '98126': SimpleZipcode(zipcode='98126', zipcode_type='STANDARD', major_city='Seattle', post_office_city='Seattle, WA', common_city_list=['Seattle'], county='King County', state='WA', lat=47.55, lng=-122.37, timezone='America/Los_Angeles', radius_in_miles=4.0, area_code_list='206', population=20698, population_density=6732.0, land_area_in_sqmi=3.07, water_area_in_sqmi=0.69, housing_units=9805, occupied_housing_units=9190, median_home_value=358100, median_household_income=66408, bounds_west=-122.399949, bounds_east=-122.359978, bounds_north=47.600639, bounds_south=47.51229),
#  '99344': SimpleZipcode(zipcode='99344', zipcode_type='STANDARD', major_city='Othello', post_office_city='Othello, WA', common_city_list=['Othello', 'Hatton'], county='Adams County', state='WA', lat=46.8, lng=-119.15, timezone='America/Los_Angeles', radius_in_miles=27.0, area_code_list='509', population=16817, population_density=37.0, land_area_in_sqmi=453.51, water_area_in_sqmi=4.46, housing_units=5105, occupied_housing_units=4677, median_home_value=137000, median_household_income=43588, bounds_west=-119.562376, bounds_east=-118.74976, bounds_north=46.985405, bounds_south=46.604803),
#  '98273': SimpleZipcode(zipcode='98273', zipcode_type='STANDARD', major_city='Mount Vernon', post_office_city='Mount Vernon, WA', common_city_list=['Mount Vernon'], county='Skagit County', state='WA', lat=48.42, lng=-122.42, timezone='America/Los_Angeles', radius_in_miles=14.0, area_code_list='360', population=28717, population_density=341.0, land_area_in_sqmi=84.09, water_area_in_sqmi=4.82, housing_units=10954, occupied_housing_units=10248, median_home_value=238800, median_household_income=48350, bounds_west=-122.51507, bounds_east=-122.191436, bounds_north=48.501219, bounds_south=48.297535),
#  '98382': SimpleZipcode(zipcode='98382', zipcode_type='STANDARD', major_city='Sequim', post_office_city='Sequim, WA', common_city_list=['Sequim'], county='Clallam County', state='WA', lat=48.06, lng=-123.06, timezone='America/Los_Angeles', radius_in_miles=16.0, area_code_list='360', population=26856, population_density=156.0, land_area_in_sqmi=171.7, water_area_in_sqmi=0.03, housing_units=14501, occupied_housing_units=12736, median_home_value=251000, median_household_income=47771, bounds_west=-123.250758, bounds_east=-122.872975, bounds_north=48.184952, bounds_south=47.866673),
#  '98833': SimpleZipcode(zipcode='98833', zipcode_type='STANDARD', major_city='Mazama', post_office_city='Mazama, WA', common_city_list=['Mazama'], county='Okanogan County', state='WA', lat=48.59, lng=-120.39, timezone='America/Los_Angeles', radius_in_miles=14.0, area_code_list='509', population=150, population_density=1.0, land_area_in_sqmi=201.59, water_area_in_sqmi=0.07, housing_units=360, occupied_housing_units=73, median_home_value=540000, median_household_income=78409, bounds_west=-120.789047, bounds_east=-120.362749, bounds_north=48.898894, bounds_south=48.514215),
#  '98121': SimpleZipcode(zipcode='98121', zipcode_type='STANDARD', major_city='Seattle', post_office_city='Seattle, WA', common_city_list=['Seattle'], county='King County', state='WA', lat=47.62, lng=-122.35, timezone='America/Los_Angeles', radius_in_miles=0.8522727272727273, area_code_list='206,360,425', population=12628, population_density=28659.0, land_area_in_sqmi=0.44, water_area_in_sqmi=0.21, housing_units=10149, occupied_housing_units=8668, median_home_value=417100, median_household_income=59355, bounds_west=-122.369903, bounds_east=-122.334304, bounds_north=47.619766, bounds_south=47.60901),
#  '98816': SimpleZipcode(zipcode='98816', zipcode_type='STANDARD', major_city='Chelan', post_office_city='Chelan, WA', common_city_list=['Chelan'], county='Chelan County', state='WA', lat=47.89, lng=-119.99, timezone='America/Los_Angeles', radius_in_miles=47.0, area_code_list='509', population=6394, population_density=16.0, land_area_in_sqmi=396.62, water_area_in_sqmi=41.1, housing_units=4676, occupied_housing_units=2523, median_home_value=388900, median_household_income=51411, bounds_west=-120.963184, bounds_east=-119.859708, bounds_north=48.244447, bounds_south=47.760367),
#  '98862': SimpleZipcode(zipcode='98862', zipcode_type='STANDARD', major_city='Winthrop', post_office_city='Winthrop, WA', common_city_list=['Winthrop'], county='Okanogan County', state='WA', lat=48.5, lng=-120.33, timezone='America/Los_Angeles', radius_in_miles=35.0, area_code_list='509', population=2218, population_density=5.0, land_area_in_sqmi=447.95, water_area_in_sqmi=0.96, housing_units=2072, occupied_housing_units=1074, median_home_value=281700, median_household_income=46597, bounds_west=-120.853673, bounds_east=-119.905443, bounds_north=48.843171, bounds_south=48.373635),
#  '98841': SimpleZipcode(zipcode='98841', zipcode_type='STANDARD', major_city='Omak', post_office_city='Omak, WA', common_city_list=['Omak'], county='Okanogan County', state='WA', lat=48.36, lng=-119.27, timezone='America/Los_Angeles', radius_in_miles=16.0, area_code_list='509', population=9197, population_density=24.0, land_area_in_sqmi=383.73, water_area_in_sqmi=6.02, housing_units=3866, occupied_housing_units=3618, median_home_value=154900, median_household_income=42725, bounds_west=-119.60358, bounds_east=-118.843439, bounds_north=48.501992, bounds_south=48.157989),
#  '98826': SimpleZipcode(zipcode='98826', zipcode_type='STANDARD', major_city='Leavenworth', post_office_city='Leavenworth, WA', common_city_list=['Leavenworth'], county='Chelan County', state='WA', lat=47.81, lng=-120.86, timezone='America/Los_Angeles', radius_in_miles=27.0, area_code_list='360', population=6504, population_density=6.0, land_area_in_sqmi=1015.96, water_area_in_sqmi=8.0, housing_units=5598, occupied_housing_units=2845, median_home_value=310200, median_household_income=49559, bounds_west=-121.180713, bounds_east=-120.441951, bounds_north=48.180575, bounds_south=47.449657),
#  '98846': SimpleZipcode(zipcode='98846', zipcode_type='STANDARD', major_city='Pateros', post_office_city='Pateros, WA', common_city_list=['Pateros'], county='Okanogan County', state='WA', lat=48.01, lng=-119.97, timezone='America/Los_Angeles', radius_in_miles=10.0, area_code_list='509', population=1173, population_density=13.0, land_area_in_sqmi=89.07, water_area_in_sqmi=2.54, housing_units=603, occupied_housing_units=443, median_home_value=223100, median_household_income=45625, bounds_west=-120.15049, bounds_east=-119.844071, bounds_north=48.156552, bounds_south=47.960203),
#  '98642': SimpleZipcode(zipcode='98642', zipcode_type='STANDARD', major_city='Ridgefield', post_office_city='Ridgefield, WA', common_city_list=['Ridgefield'], county='Clark County', state='WA', lat=45.79, lng=-122.69, timezone='America/Los_Angeles', radius_in_miles=7.0, area_code_list='360', population=15696, population_density=275.0, land_area_in_sqmi=57.09, water_area_in_sqmi=2.99, housing_units=5991, occupied_housing_units=5672, median_home_value=330800, median_household_income=78108, bounds_west=-122.795963, bounds_east=-122.606945, bounds_north=45.873171, bounds_south=45.730401),
#  '98616': SimpleZipcode(zipcode='98616', zipcode_type='STANDARD', major_city='Cougar', post_office_city='Cougar, WA', common_city_list=['Cougar'], county='Cowlitz County', state='WA', lat=46.19, lng=-122.13, timezone='America/Los_Angeles', radius_in_miles=7.0, area_code_list='360', population=150, population_density=1.0, land_area_in_sqmi=207.44, water_area_in_sqmi=10.02, housing_units=472, occupied_housing_units=73, median_home_value=218900, median_household_income=45167, bounds_west=-122.332836, bounds_east=-121.996963, bounds_north=46.386446, bounds_south=46.037941),
#  '98424': SimpleZipcode(zipcode='98424', zipcode_type='STANDARD', major_city='Fife', post_office_city='Tacoma, WA', common_city_list=['Tacoma', 'Fife'], county='Pierce County', state='WA', lat=47.23, lng=-122.36, timezone='America/Los_Angeles', radius_in_miles=3.0, area_code_list='253', population=10140, population_density=1608.0, land_area_in_sqmi=6.31, water_area_in_sqmi=0.14, housing_units=4229, occupied_housing_units=3952, median_home_value=242300, median_household_income=58892, bounds_west=-122.399685, bounds_east=-122.320413, bounds_north=47.258683, bounds_south=47.207197),
#  '98337': SimpleZipcode(zipcode='98337', zipcode_type='STANDARD', major_city='Bremerton', post_office_city='Bremerton, WA', common_city_list=['Bremerton', 'Gorst'], county='Kitsap County', state='WA', lat=47.57, lng=-122.63, timezone='America/Los_Angeles', radius_in_miles=1.0, area_code_list='360', population=6697, population_density=6414.0, land_area_in_sqmi=1.04, water_area_in_sqmi=0.69, housing_units=3436, occupied_housing_units=2925, median_home_value=178500, median_household_income=38826, bounds_west=-122.652264, bounds_east=-122.607123, bounds_north=47.583662, bounds_south=47.553081),
#  '98230': SimpleZipcode(zipcode='98230', zipcode_type='STANDARD', major_city='Blaine', post_office_city='Blaine, WA', common_city_list=['Blaine'], county='Whatcom County', state='WA', lat=48.93, lng=-122.72, timezone='America/Los_Angeles', radius_in_miles=27.0, area_code_list='360', population=15710, population_density=359.0, land_area_in_sqmi=43.76, water_area_in_sqmi=4.81, housing_units=8802, occupied_housing_units=6553, median_home_value=249700, median_household_income=56641, bounds_west=-122.822464, bounds_east=-122.550704, bounds_north=49.002445, bounds_south=48.854624),
#  '98801': SimpleZipcode(zipcode='98801', zipcode_type='STANDARD', major_city='Wenatchee', post_office_city='Wenatchee, WA', common_city_list=['Wenatchee'], county='Chelan County', state='WA', lat=47.37, lng=-120.35, timezone='America/Los_Angeles', radius_in_miles=19.0, area_code_list='509', population=40977, population_density=252.0, land_area_in_sqmi=162.32, water_area_in_sqmi=3.82, housing_units=16686, occupied_housing_units=15654, median_home_value=225900, median_household_income=51176, bounds_west=-120.458818, bounds_east=-120.192083, bounds_north=47.643068, bounds_south=47.260873),
#  '98226': SimpleZipcode(zipcode='98226', zipcode_type='STANDARD', major_city='Bellingham', post_office_city='Bellingham, WA', common_city_list=['Bellingham'], county='Whatcom County', state='WA', lat=48.79, lng=-122.41, timezone='America/Los_Angeles', radius_in_miles=16.0, area_code_list='360', population=41235, population_density=385.0, land_area_in_sqmi=107.23, water_area_in_sqmi=12.57, housing_units=17623, occupied_housing_units=16520, median_home_value=291000, median_household_income=55952, bounds_west=-122.708422, bounds_east=-122.255131, bounds_north=48.887888, bounds_south=48.690119),
#  '98421': SimpleZipcode(zipcode='98421', zipcode_type='STANDARD', major_city='Tacoma', post_office_city='Tacoma, WA', common_city_list=['Tacoma'], county='Pierce County', state='WA', lat=47.26, lng=-122.39, timezone='America/Los_Angeles', radius_in_miles=3.0, area_code_list='253', population=None, population_density=None, land_area_in_sqmi=None, water_area_in_sqmi=None, housing_units=None, occupied_housing_units=None, median_home_value=None, median_household_income=None, bounds_west=-122.438331, bounds_east=-122.356625, bounds_north=47.287583, bounds_south=47.233235),
#  '98105': SimpleZipcode(zipcode='98105', zipcode_type='STANDARD', major_city='Seattle', post_office_city='Seattle, WA', common_city_list=['Seattle'], county='King County', state='WA', lat=47.66, lng=-122.29, timezone='America/Los_Angeles', radius_in_miles=2.0, area_code_list='206', population=43924, population_density=10643.0, land_area_in_sqmi=4.13, water_area_in_sqmi=2.48, housing_units=17161, occupied_housing_units=15939, median_home_value=613900, median_household_income=45560, bounds_west=-122.331545, bounds_east=-122.231435, bounds_north=47.674493, bounds_south=47.64712),
#  '98034': SimpleZipcode(zipcode='98034', zipcode_type='STANDARD', major_city='Kirkland', post_office_city='Kirkland, WA', common_city_list=['Kirkland'], county='King County', state='WA', lat=47.72, lng=-122.2, timezone='America/Los_Angeles', radius_in_miles=4.0, area_code_list='425,206', population=40407, population_density=4428.0, land_area_in_sqmi=9.13, water_area_in_sqmi=1.69, housing_units=17880, occupied_housing_units=16891, median_home_value=364900, median_household_income=77688, bounds_west=-122.269937, bounds_east=-122.151867, bounds_north=47.74266, bounds_south=47.69012),
#  '98204': SimpleZipcode(zipcode='98204', zipcode_type='STANDARD', major_city='Everett', post_office_city='Everett, WA', common_city_list=['Everett'], county='Snohomish County', state='WA', lat=47.89, lng=-122.25, timezone='America/Los_Angeles', radius_in_miles=3.0, area_code_list='425', population=39380, population_density=4908.0, land_area_in_sqmi=8.02, water_area_in_sqmi=0.0, housing_units=17330, occupied_housing_units=15996, median_home_value=200900, median_household_income=41517, bounds_west=-122.293251, bounds_east=-122.224129, bounds_north=47.924536, bounds_south=47.872431),
#  '98632': SimpleZipcode(zipcode='98632', zipcode_type='STANDARD', major_city='Longview', post_office_city='Longview, WA', common_city_list=['Longview'], county='Cowlitz County', state='WA', lat=46.19, lng=-123.05, timezone='America/Los_Angeles', radius_in_miles=11.0, area_code_list='360', population=49205, population_density=381.0, land_area_in_sqmi=129.13, water_area_in_sqmi=8.17, housing_units=21383, occupied_housing_units=19985, median_home_value=177900, median_household_income=42930, bounds_west=-123.240393, bounds_east=-122.866234, bounds_north=46.333211, bounds_south=46.045974),
#  '98802': SimpleZipcode(zipcode='98802', zipcode_type='STANDARD', major_city='East Wenatchee', post_office_city='East Wenatchee, WA', common_city_list=['East Wenatchee', 'E Wenatchee', 'Wenatchee'], county='Douglas County', state='WA', lat=47.49, lng=-120.19, timezone='America/Los_Angeles', radius_in_miles=14.0, area_code_list='509', population=28719, population_density=160.0, land_area_in_sqmi=179.46, water_area_in_sqmi=3.13, housing_units=11297, occupied_housing_units=10565, median_home_value=220100, median_household_income=56893, bounds_west=-120.318084, bounds_east=-120.025205, bounds_north=47.670786, bounds_south=47.345671),
#  '99336': SimpleZipcode(zipcode='99336', zipcode_type='STANDARD', major_city='Kennewick', post_office_city='Kennewick, WA', common_city_list=['Kennewick'], county='Benton County', state='WA', lat=46.21, lng=-119.16, timezone='America/Los_Angeles', radius_in_miles=6.0, area_code_list='509', population=48753, population_density=3653.0, land_area_in_sqmi=13.35, water_area_in_sqmi=1.39, housing_units=19401, occupied_housing_units=18372, median_home_value=146100, median_household_income=41990, bounds_west=-119.259221, bounds_east=-119.093314, bounds_north=46.241229, bounds_south=46.194179),
#  '98065': SimpleZipcode(zipcode='98065', zipcode_type='STANDARD', major_city='Snoqualmie', post_office_city='Snoqualmie, WA', common_city_list=['Snoqualmie'], county='King County', state='WA', lat=47.53, lng=-121.8, timezone='America/Los_Angeles', radius_in_miles=11.0, area_code_list='', population=12699, population_density=171.0, land_area_in_sqmi=74.09, water_area_in_sqmi=0.87, housing_units=4556, occupied_housing_units=4278, median_home_value=418900, median_household_income=121415, bounds_west=-121.908721, bounds_east=-121.697603, bounds_north=47.700723, bounds_south=47.447451),
#  '98275': SimpleZipcode(zipcode='98275', zipcode_type='STANDARD', major_city='Mukilteo', post_office_city='Mukilteo, WA', common_city_list=['Mukilteo'], county='Snohomish County', state='WA', lat=47.91, lng=-122.3, timezone='America/Los_Angeles', radius_in_miles=4.0, area_code_list='', population=20256, population_density=2654.0, land_area_in_sqmi=7.63, water_area_in_sqmi=1.0, housing_units=8548, occupied_housing_units=8058, median_home_value=439400, median_household_income=93717, bounds_west=-122.332038, bounds_east=-122.260699, bounds_north=47.956435, bounds_south=47.874403),
# ...
#  '98391': SimpleZipcode(zipcode='98391', zipcode_type='STANDARD', major_city='Bonney Lake', post_office_city='Bonney Lake, WA', common_city_list=['Bonney Lake', 'Lake Tapps', 'Sumner'], county='Pierce County', state='WA', lat=47.18, lng=-122.16, timezone='America/Los_Angeles', radius_in_miles=9.0, area_code_list='', population=44309, population_density=1149.0, land_area_in_sqmi=38.57, water_area_in_sqmi=1.01, housing_units=16281, occupied_housing_units=15325, median_home_value=268000, median_household_income=83560, bounds_west=-122.226241, bounds_east=-122.11286, bounds_north=47.257808, bounds_south=47.088233),
#  '98022': SimpleZipcode(zipcode='98022', zipcode_type='STANDARD', major_city='Enumclaw', post_office_city='Enumclaw, WA', common_city_list=['Enumclaw'], county='King County', state='WA', lat=47.1, lng=-121.6, timezone='America/Los_Angeles', radius_in_miles=28.0, area_code_list='360', population=20987, population_density=52.0, land_area_in_sqmi=405.93, water_area_in_sqmi=2.45, housing_units=9179, occupied_housing_units=8296, median_home_value=300800, median_household_income=66295, bounds_west=-122.115686, bounds_east=-121.298041, bounds_north=47.321498, bounds_south=46.909053),
#  '98053': SimpleZipcode(zipcode='98053', zipcode_type='STANDARD', major_city='Redmond', post_office_city='Redmond, WA', common_city_list=['Redmond'], county='King County', state='WA', lat=47.66, lng=-122.01, timezone='America/Los_Angeles', radius_in_miles=6.0, area_code_list='206,425', population=18784, population_density=662.0, land_area_in_sqmi=28.37, water_area_in_sqmi=0.18, housing_units=7652, occupied_housing_units=7108, median_home_value=544500, median_household_income=116518, bounds_west=-122.091534, bounds_east=-121.949583, bounds_north=47.726518, bounds_south=47.594577),
#  '98311': SimpleZipcode(zipcode='98311', zipcode_type='STANDARD', major_city='Bremerton', post_office_city='Bremerton, WA', common_city_list=['Bremerton'], county='Kitsap County', state='WA', lat=47.63, lng=-122.63, timezone='America/Los_Angeles', radius_in_miles=3.0, area_code_list='206,360', population=25880, population_density=2384.0, land_area_in_sqmi=10.86, water_area_in_sqmi=3.68, housing_units=10305, occupied_housing_units=9614, median_home_value=227900, median_household_income=66706, bounds_west=-122.691957, bounds_east=-122.585059, bounds_north=47.666588, bounds_south=47.596218),
#  '98674': SimpleZipcode(zipcode='98674', zipcode_type='STANDARD', major_city='Woodland', post_office_city='Woodland, WA', common_city_list=['Woodland'], county='Cowlitz County', state='WA', lat=45.94, lng=-122.67, timezone='America/Los_Angeles', radius_in_miles=12.0, area_code_list='360', population=12029, population_density=145.0, land_area_in_sqmi=82.95, water_area_in_sqmi=4.55, housing_units=4606, occupied_housing_units=4316, median_home_value=245100, median_household_income=64572, bounds_west=-122.812215, bounds_east=-122.451694, bounds_north=46.025194, bounds_south=45.850536),
#  '98541': SimpleZipcode(zipcode='98541', zipcode_type='STANDARD', major_city='Elma', post_office_city='Elma, WA', common_city_list=['Elma'], county='Grays Harbor County', state='WA', lat=47.1, lng=-123.39, timezone='America/Los_Angeles', radius_in_miles=20.0, area_code_list='360', population=10101, population_density=48.0, land_area_in_sqmi=211.42, water_area_in_sqmi=1.76, housing_units=4434, occupied_housing_units=3849, median_home_value=175900, median_household_income=48202, bounds_west=-123.548651, bounds_east=-123.15843, bounds_north=47.300094, bounds_south=46.897906),
#  '99032': SimpleZipcode(zipcode='99032', zipcode_type='STANDARD', major_city='Sprague', post_office_city='Sprague, WA', common_city_list=['Sprague'], county='Lincoln County', state='WA', lat=47.33, lng=-118.04, timezone='America/Los_Angeles', radius_in_miles=17.0, area_code_list='509', population=691, population_density=3.0, land_area_in_sqmi=217.37, water_area_in_sqmi=3.58, housing_units=351, occupied_housing_units=298, median_home_value=135700, median_household_income=42938, bounds_west=-118.251954, bounds_east=-117.822877, bounds_north=47.447613, bounds_south=47.13342),
#  '99208': SimpleZipcode(zipcode='99208', zipcode_type='STANDARD', major_city='Spokane', post_office_city='Spokane, WA', common_city_list=['Spokane'], county='Spokane County', state='WA', lat=47.78, lng=-117.45, timezone='America/Los_Angeles', radius_in_miles=9.0, area_code_list='509', population=49193, population_density=1001.0, land_area_in_sqmi=49.16, water_area_in_sqmi=0.11, housing_units=20688, occupied_housing_units=19481, median_home_value=210800, median_household_income=53820, bounds_west=-117.546165, bounds_east=-117.361192, bounds_north=47.860211, bounds_south=47.700776),
#  '98620': SimpleZipcode(zipcode='98620', zipcode_type='STANDARD', major_city='Goldendale', post_office_city='Goldendale, WA', common_city_list=['Goldendale'], county='Klickitat County', state='WA', lat=45.84, lng=-120.76, timezone='America/Los_Angeles', radius_in_miles=44.0, area_code_list='509', population=7123, population_density=15.0, land_area_in_sqmi=486.55, water_area_in_sqmi=5.79, housing_units=3515, occupied_housing_units=3011, median_home_value=142400, median_household_income=36846, bounds_west=-121.131126, bounds_east=-120.431582, bounds_north=46.018991, bounds_south=45.650038),
#  '98404': SimpleZipcode(zipcode='98404', zipcode_type='STANDARD', major_city='Tacoma', post_office_city='Tacoma, WA', common_city_list=['Tacoma'], county='Pierce County', state='WA', lat=47.2, lng=-122.4, timezone='America/Los_Angeles', radius_in_miles=3.0, area_code_list='253', population=32086, population_density=4214.0, land_area_in_sqmi=7.61, water_area_in_sqmi=0.02, housing_units=11390, occupied_housing_units=10522, median_home_value=167800, median_household_income=43832, bounds_west=-122.431595, bounds_east=-122.381899, bounds_north=47.24097, bounds_south=47.179969),
#  '98418': SimpleZipcode(zipcode='98418', zipcode_type='STANDARD', major_city='Tacoma', post_office_city='Tacoma, WA', common_city_list=['Tacoma'], county='Pierce County', state='WA', lat=47.22, lng=-122.44, timezone='America/Los_Angeles', radius_in_miles=1.0, area_code_list='253', population=10069, population_density=5982.0, land_area_in_sqmi=1.68, water_area_in_sqmi=0.0, housing_units=4279, occupied_housing_units=3884, median_home_value=173600, median_household_income=45633, bounds_west=-122.463298, bounds_east=-122.428974, bounds_north=47.233391, bounds_south=47.214638),
#  '98239': SimpleZipcode(zipcode='98239', zipcode_type='STANDARD', major_city='Coupeville', post_office_city='Coupeville, WA', common_city_list=['Coupeville'], county='Island County', state='WA', lat=48.18, lng=-122.66, timezone='America/Los_Angeles', radius_in_miles=7.0, area_code_list='360', population=6646, population_density=227.0, land_area_in_sqmi=29.27, water_area_in_sqmi=13.34, housing_units=3714, occupied_housing_units=2986, median_home_value=313400, median_household_income=60275, bounds_west=-122.782201, bounds_east=-122.566602, bounds_north=48.253812, bounds_south=48.10905),
#  '98664': SimpleZipcode(zipcode='98664', zipcode_type='STANDARD', major_city='Vancouver', post_office_city='Vancouver, WA', common_city_list=['Vancouver'], county='Clark County', state='WA', lat=45.62, lng=-122.57, timezone='America/Los_Angeles', radius_in_miles=2.0, area_code_list='360', population=21771, population_density=4141.0, land_area_in_sqmi=5.26, water_area_in_sqmi=0.3, housing_units=9487, occupied_housing_units=8964, median_home_value=196200, median_household_income=53290, bounds_west=-122.607706, bounds_east=-122.548529, bounds_north=45.642057, bounds_south=45.597269),
#  '98030': SimpleZipcode(zipcode='98030', zipcode_type='STANDARD', major_city='Kent', post_office_city='Kent, WA', common_city_list=['Kent'], county='King County', state='WA', lat=47.36, lng=-122.19, timezone='America/Los_Angeles', radius_in_miles=2.0, area_code_list='253', population=33769, population_density=4741.0, land_area_in_sqmi=7.12, water_area_in_sqmi=0.09, housing_units=12739, occupied_housing_units=11900, median_home_value=251700, median_household_income=51446, bounds_west=-122.231109, bounds_east=-122.165402, bounds_north=47.386957, bounds_south=47.343414),
#  '98292': SimpleZipcode(zipcode='98292', zipcode_type='STANDARD', major_city='Stanwood', post_office_city='Stanwood, WA', common_city_list=['Stanwood'], county='Snohomish County', state='WA', lat=48.21, lng=-122.28, timezone='America/Los_Angeles', radius_in_miles=10.0, area_code_list='360', population=20987, population_density=282.0, land_area_in_sqmi=74.5, water_area_in_sqmi=5.65, housing_units=8779, occupied_housing_units=7938, median_home_value=300900, median_household_income=72457, bounds_west=-122.405747, bounds_east=-122.203917, bounds_north=48.308495, bounds_south=48.119252),
#  '98507': SimpleZipcode(zipcode='98507', zipcode_type='PO BOX', major_city='Olympia', post_office_city=None, common_city_list=['Olympia'], county='Thurston County', state='WA', lat=47.03, lng=-122.87, timezone='America/Los_Angeles', radius_in_miles=None, area_code_list='360', population=None, population_density=None, land_area_in_sqmi=None, water_area_in_sqmi=None, housing_units=None, occupied_housing_units=None, median_home_value=None, median_household_income=None, bounds_west=None, bounds_east=None, bounds_north=None, bounds_south=None),
#  '98671': SimpleZipcode(zipcode='98671', zipcode_type='STANDARD', major_city='Washougal', post_office_city='Washougal, WA', common_city_list=['Washougal'], county='Clark County', state='WA', lat=45.61, lng=-122.23, timezone='America/Los_Angeles', radius_in_miles=16.0, area_code_list='360', population=21220, population_density=246.0, land_area_in_sqmi=86.3, water_area_in_sqmi=6.24, housing_units=8593, occupied_housing_units=7934, median_home_value=254100, median_household_income=68358, bounds_west=-122.386138, bounds_east=-122.085594, bounds_north=45.689501, bounds_south=45.543541),
#  '98241': SimpleZipcode(zipcode='98241', zipcode_type='STANDARD', major_city='Darrington', post_office_city='Darrington, WA', common_city_list=['Darrington'], county='Snohomish County', state='WA', lat=48.19, lng=-121.21, timezone='America/Los_Angeles', radius_in_miles=13.0, area_code_list='360', population=2129, population_density=5.0, land_area_in_sqmi=409.34, water_area_in_sqmi=2.53, housing_units=1024, occupied_housing_units=876, median_home_value=185300, median_household_income=39280, bounds_west=-121.688197, bounds_east=-120.906211, bounds_north=48.384516, bounds_south=48.025887),
#  '98937': SimpleZipcode(zipcode='98937', zipcode_type='STANDARD', major_city='Naches', post_office_city='Naches, WA', common_city_list=['Naches', 'Goose Prairie'], county='Yakima County', state='WA', lat=46.78, lng=-120.88, timezone='America/Los_Angeles', radius_in_miles=53.0, area_code_list='509', population=4112, population_density=5.0, land_area_in_sqmi=784.94, water_area_in_sqmi=7.41, housing_units=2478, occupied_housing_units=1633, median_home_value=193500, median_household_income=46429, bounds_west=-121.52327, bounds_east=-120.594043, bounds_north=47.088954, bounds_south=46.578633),
#  '98571': SimpleZipcode(zipcode='98571', zipcode_type='PO BOX', major_city='Pacific Beach', post_office_city='Pacific Beach, WA', common_city_list=['Pacific Beach'], county='Grays Harbor County', state='WA', lat=47.21, lng=-124.19, timezone='America/Los_Angeles', radius_in_miles=0.17045454545454544, area_code_list='360', population=483, population_density=55.0, land_area_in_sqmi=8.76, water_area_in_sqmi=1.08, housing_units=447, occupied_housing_units=204, median_home_value=577500, median_household_income=57195, bounds_west=-124.223427, bounds_east=-124.114498, bounds_north=47.244698, bounds_south=47.171596),
#  '99006': SimpleZipcode(zipcode='99006', zipcode_type='STANDARD', major_city='Deer Park', post_office_city='Deer Park, WA', common_city_list=['Deer Park'], county='Spokane County', state='WA', lat=47.99, lng=-117.5, timezone='America/Los_Angeles', radius_in_miles=17.0, area_code_list='509', population=11946, population_density=65.0, land_area_in_sqmi=183.64, water_area_in_sqmi=0.47, housing_units=4765, occupied_housing_units=4392, median_home_value=186700, median_household_income=49576, bounds_west=-117.735428, bounds_east=-117.34959, bounds_north=48.194756, bounds_south=47.830619),
#  '98532': SimpleZipcode(zipcode='98532', zipcode_type='STANDARD', major_city='Chehalis', post_office_city='Chehalis, WA', common_city_list=['Chehalis', 'Napavine'], county='Lewis County', state='WA', lat=46.62, lng=-123.0, timezone='America/Los_Angeles', radius_in_miles=27.0, area_code_list='360', population=23596, population_density=73.0, land_area_in_sqmi=322.54, water_area_in_sqmi=1.07, housing_units=9580, occupied_housing_units=8919, median_home_value=210600, median_household_income=49762, bounds_west=-123.369679, bounds_east=-122.616877, bounds_north=46.763537, bounds_south=46.442947),
#  '98375': SimpleZipcode(zipcode='98375', zipcode_type='STANDARD', major_city='Puyallup', post_office_city='Puyallup, WA', common_city_list=['Puyallup', 'South Hill'], county='Pierce County', state='WA', lat=47.1, lng=-122.32, timezone='America/Los_Angeles', radius_in_miles=3.0, area_code_list='253', population=26863, population_density=2764.0, land_area_in_sqmi=9.72, water_area_in_sqmi=0.0, housing_units=9270, occupied_housing_units=8699, median_home_value=220000, median_household_income=70373, bounds_west=-122.361674, bounds_east=-122.282607, bounds_north=47.126088, bounds_south=47.071506),
#  '98948': SimpleZipcode(zipcode='98948', zipcode_type='STANDARD', major_city='Toppenish', post_office_city='Toppenish, WA', common_city_list=['Toppenish'], county='Yakima County', state='WA', lat=46.28, lng=-120.25, timezone='America/Los_Angeles', radius_in_miles=22.0, area_code_list='509', population=13225, population_density=61.0, land_area_in_sqmi=218.21, water_area_in_sqmi=0.11, housing_units=3701, occupied_housing_units=3495, median_home_value=116600, median_household_income=35210, bounds_west=-120.565274, bounds_east=-120.125954, bounds_north=46.433868, bounds_south=46.105392),
#  '98252': SimpleZipcode(zipcode='98252', zipcode_type='STANDARD', major_city='Granite Falls', post_office_city='Granite Falls, WA', common_city_list=['Granite Falls'], county='Snohomish County', state='WA', lat=48.05, lng=-121.74, timezone='America/Los_Angeles', radius_in_miles=40.0, area_code_list='360', population=8777, population_density=33.0, land_area_in_sqmi=267.28, water_area_in_sqmi=2.06, housing_units=3736, occupied_housing_units=3272, median_home_value=226900, median_household_income=70726, bounds_west=-122.046349, bounds_east=-121.433231, bounds_north=48.218852, bounds_south=47.969594),
#  '98270': SimpleZipcode(zipcode='98270', zipcode_type='STANDARD', major_city='Marysville', post_office_city='Marysville, WA', common_city_list=['Marysville'], county='Snohomish County', state='WA', lat=48.05, lng=-122.14, timezone='America/Los_Angeles', radius_in_miles=5.0, area_code_list='360', population=45899, population_density=3208.0, land_area_in_sqmi=14.31, water_area_in_sqmi=0.17, housing_units=17093, occupied_housing_units=16219, median_home_value=242100, median_household_income=65130, bounds_west=-122.184725, bounds_east=-122.109388, bounds_north=48.097998, bounds_south=48.020006),
#  'G9N 0': None,
#  '99207': SimpleZipcode(zipcode='99207', zipcode_type='STANDARD', major_city='Spokane', post_office_city='Spokane, WA', common_city_list=['Spokane'], county='Spokane County', state='WA', lat=47.69, lng=-117.38, timezone='America/Los_Angeles', radius_in_miles=2.0, area_code_list='509', population=30854, population_density=5663.0, land_area_in_sqmi=5.45, water_area_in_sqmi=0.06, housing_units=13130, occupied_housing_units=12181, median_home_value=116600, median_household_income=32183, bounds_west=-117.413848, bounds_east=-117.346716, bounds_north=47.711498, bounds_south=47.671723)}
